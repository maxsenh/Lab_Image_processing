# %% [markdown]
# # Lab Image Processing Class
# ## Image Classification with Keras/Tensorflow

# %% [markdown]
# ### Code for using google collab
#
# First we will zip the local data from our computer with
# ```bash
# zip -r zip_file.zip folder_to_zip/
# ```
# and then we will upload the file to our google drive.
# In the next step, we will mount our google drive.

# %%
from google.colab import drive
drive.mount('/content/drive')#, force_remount = True)
# Out:
# Mounted at /content/drive

# %%
# Create folder to store the zipped data and copy the data from the google drive
# to our cloud computing space
# !mkdir zipped_data/
# !cp /content/drive/MyDrive/beach_forests.zip zipped_data/

# %%
# !unzip /content/zipped_data/beach_forests.zip
# Out:
# Archive:  /content/zipped_data/beach_forest.zip
#    creating: own_image_data/
#   inflating: own_image_data/.DS_Store
#    creating: own_image_data/models/
#    creating: own_image_data/models/beach_forest_50epoch/
#    creating: own_image_data/models/beach_forest_50epoch/variables/
#   inflating: own_image_data/models/beach_forest_50epoch/variables/variables.data-00000-of-00001
#   inflating: own_image_data/models/beach_forest_50epoch/variables/variables.index
#   inflating: own_image_data/models/beach_forest_50epoch/saved_model.pb
#    creating: own_image_data/models/beach_forest_50epoch/assets/
#    creating: own_image_data/models/beachforest_50epo_transfer/
#    creating: own_image_data/models/beachforest_50epo_transfer/variables/
#   inflating: own_image_data/models/beachforest_50epo_transfer/variables/variables.data-00000-of-00001
#   inflating: own_image_data/models/beachforest_50epo_transfer/variables/variables.index
#   inflating: own_image_data/models/beachforest_50epo_transfer/saved_model.pb
#    creating: own_image_data/models/beachforest_50epo_transfer/assets/
#    creating: own_image_data/Inf/
#    creating: own_image_data/Inf/forest/
#   inflating: own_image_data/Inf/forest/.DS_Store
#   inflating: own_image_data/Inf/forest/4.file-20191209-90562-nsnsun.jpg
#   inflating: own_image_data/Inf/forest/25.fallback_skogsagare.jpg
#   inflating: own_image_data/Inf/forest/40.chris-ward-mckinley-woods-3.jpg.aspx.jpg
#   inflating: own_image_data/Inf/forest/17.final-cover-forest.jpg
#   inflating: own_image_data/Inf/forest/18.tallar_i_skog_3431.jpeg
#   inflating: own_image_data/Inf/forest/2.image.jpg
#   inflating: own_image_data/Inf/forest/8.1612549734blobid1.jpg
#   inflating: own_image_data/Inf/forest/20.604599-gettyimages-1083893950.jpg
#    creating: own_image_data/Inf/beach/
#   inflating: own_image_data/Inf/beach/9.bondi-beach-sydney.jpg
#   inflating: own_image_data/Inf/beach/.DS_Store
#   inflating: own_image_data/Inf/beach/20.laem-singh-beach-phuket.jpg
#   inflating: own_image_data/Inf/beach/14.tropical_beach_helsingborg_2010-07-14_04-scaled.jpg
#   inflating: own_image_data/Inf/beach/24.beach.jpg
#   inflating: own_image_data/Inf/beach/30.12%20anse.jpg
#   inflating: own_image_data/Inf/beach/30.greece-beaches-1280.jpg
#   inflating: own_image_data/Inf/beach/26.maxresdefault.jpg
#   inflating: own_image_data/Inf/beach/24.es-trenc-beach-mallorca-1.jpg
#   inflating: own_image_data/Inf/beach/26.c33313e6-7a75-4897-bae2-724b3a66958a.jpg
#    creating: own_image_data/Train/
#    creating: own_image_data/Train/forest/
#   inflating: own_image_data/Train/forest/18.sonaliranade_scots-pine_forest.jpg
#   inflating: own_image_data/Train/forest/38.the-red-forest-416x290-cm-premium-non-woven-wallpaper-130gsm-i53880.jpg
#   inflating: own_image_data/Val/forest/14.forest-web.jpg
#   inflating: own_image_data/Val/forest/28.foggy-forest.jpg
#   inflating: own_image_data/Val/forest/3.image.jpg
#   inflating: own_image_data/Val/forest/28.landscape-4350845_1920.jpg
#   inflating: own_image_data/Val/forest/33.tuce-p3dxoe-ojga-unsplash.jpg
#   inflating: own_image_data/Val/forest/7.warming-green-forest.jpg
#   inflating: own_image_data/Val/forest/4.2-forest.jpg
#   inflating: own_image_data/Val/forest/45.rewilding_fire.jpg
#   inflating: own_image_data/Val/forest/7.cropped-forest-pathology-bokfo%cc%88rsta.jpg
#   inflating: own_image_data/Val/forest/25.bakgrund-sns-scaled.jpg
#   inflating: own_image_data/Val/forest/39.science_forestfloor_1150219457.jpg
#   inflating: own_image_data/Val/forest/43.img_6159.jpg
#   inflating: own_image_data/Val/forest/3.rs930_135120665-low.jpg
#   inflating: own_image_data/Val/forest/37.buchenwald_fr%c3%bchling.jpg
#    creating: own_image_data/Val/beach/
#   inflating: own_image_data/Val/beach/32.mauritius---beaches---tropical-beach.jpg
#   inflating: own_image_data/Val/beach/8.bondi-beach-sydney.jpg
#   inflating: own_image_data/Val/beach/25.c33313e6-7a75-4897-bae2-724b3a66958a.jpg
#   inflating: own_image_data/Val/beach/38.greece-beaches-1280.jpg
#   inflating: own_image_data/Val/beach/19.5bfec49248eb12058423acf7.jpg
#   inflating: own_image_data/Val/beach/35.barceloneta-beach--barcelona-catalonia-spain-e1602146991539.jpg
#   inflating: own_image_data/Val/beach/37.190426_pasea_tg_49_d8336e93-8f63-41d8-9825-e3caf4b5ce24.jpg
#   inflating: own_image_data/Val/beach/29.family-siesta-beach-florida-hero.jpg
#   inflating: own_image_data/Val/beach/2.181010131059-australia-best-beaches-cossies-beach-cocos3.jpg
#   inflating: own_image_data/Val/beach/43.playa-bolonia-tarifa_s540759601.jpg
#   inflating: own_image_data/Val/beach/33.hkttao1001_13_129.jpg
#   inflating: own_image_data/Val/beach/35.long-beach-phu-quoc-best-beaches-in-vietnam_36e9b14cff.jpeg
#   inflating: own_image_data/Val/beach/4.aerial-one&onlyreethirah-maldives-crhotel.jpg
#   inflating: own_image_data/Val/beach/34.290776_17080912020055236369.jpg
#   inflating: own_image_data/Val/beach/22.maxresdefault.jpg
#   inflating: own_image_data/Val/beach/41.6048.jpg
#   inflating: own_image_data/Val/beach/8.1200x1200-affischer-posters_2019-12_med-kant_black_beach1.jpg
#   inflating: own_image_data/Val/beach/40.palm_beach_florida_aerial_2011.jpg
#   inflating: own_image_data/Val/beach/27.12%20anse.jpg
#   inflating: own_image_data/Val/beach/31.hkttao1001_13_129.jpg

# %%
# Imports

# Miscellaneous operating system libraries
import os
import shutil
import numpy as np
import random

# Libraries for plotting
import matplotlib.pyplot as plt
import seaborn as sns
import cv2
from IPython.display import display, Image

# Deep learning libraries Keras and Tensorflow for training and sklearn for the metrics
import keras
from keras.models import Sequential
from keras.layers import Dense, Conv2D , MaxPool2D , Flatten , Dropout 
from keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import classification_report,confusion_matrix
import tensorflow as tf

# New Home folder where are our images and models are stored
HOME = '/content/own_image_data/'

# %% [markdown]
# For our example I downloaded images from Google, but you may also download images from other sources, such as [Open Images Dataset V6](https://storage.googleapis.com/openimages/web/index.html). Obviously, you can also use your own data. In any case, make sure that you define the home path properly and that the data structure is as follows:
#
# - Data
#     - Train
#         - Class 1
#         - Class 2
#     - Val
#         - Class 1
#         - Class 2
#     - Inf
#         - Class 1
#         - Class 2
#     - Models

# %% [markdown]
# ## Data preparation
#
# In the data preparation we will save the data in memory as numpy arrays, resize to the same dimensions and take a sneak peak into some of the images. Lastly, we will do data augmentation to inflate the data.

# %%
# define the classes
classes = ['beach', 'forest']

def get_data(data_dir, classes, img_size):
    data = [] 
    for label in classes: 
        path = os.path.join(data_dir, label)
        class_num = classes.index(label)
        for img in os.listdir(path):
            try:
                img_arr = cv2.imread(os.path.join(path, img))[...,::-1] #convert BGR to RGB format
                resized_arr = cv2.resize(img_arr, (img_size, img_size)) # Reshaping images to preferred size
                data.append([resized_arr, class_num])
            except Exception as e:
                print(e)
    return np.array(data, dtype=object)

# %%
# Define the target image size, the larger, the more features, but also longer training times.
img_size = 256

train = get_data(HOME + 'Train/', classes, img_size)
val = get_data(HOME + 'Val/', classes, img_size)

# %%
# View the data and review how many of the training images are availabe
# Useful to verify that we loaded all the images from the training data set as numpy arrays
# Sometimes, with faulty file endings, there might be errors
l = []
for i in train:
    if(i[1] == 0):
        l.append(classes[0])
    else:
        l.append(classes[1])
sns.set_style('darkgrid')
sns.countplot(x=l)

# %%
# Show one image from the first class
plt.figure(figsize = (5,5))
plt.imshow(train[1][0])
plt.title(classes[train[0][1]])
# Out:
# Text(0.5, 1.0, 'beach')

# %%
# show one image from the second class
plt.figure(figsize = (5,5))
plt.imshow(train[-2][0])
plt.title(classes[train[-1][1]])
# Out:
# Text(0.5, 1.0, 'forest')

# %%
# Data preprocessing

x_train = []
y_train = []
x_val = []
y_val = []

for feature, label in train:
    x_train.append(feature)
    y_train.append(label)

for feature, label in val:
    x_val.append(feature)
    y_val.append(label)

# Normalize the data
x_train = np.array(x_train) / 255
x_val = np.array(x_val) / 255

x_train.reshape(-1, img_size, img_size, 1)
y_train = np.array(y_train)

x_val.reshape(-1, img_size, img_size, 1)
y_val = np.array(y_val)

# %%
# data augmentation on training data
datagen = ImageDataGenerator(
        featurewise_center=False,  # set input mean to 0 over the dataset
        samplewise_center=False,  # set each sample mean to 0
        featurewise_std_normalization=False,  # divide inputs by std of the dataset
        samplewise_std_normalization=False,  # divide each input by its std
        zca_whitening=False,  # apply ZCA whitening
        rotation_range = 30,  # randomly rotate images in the range (degrees, 0 to 180)
        zoom_range = 0.2, # Randomly zoom image 
        width_shift_range=0.1,  # randomly shift images horizontally (fraction of total width)
        height_shift_range=0.1,  # randomly shift images vertically (fraction of total height)
        horizontal_flip = True,  # randomly flip images
        vertical_flip=False)  # randomly flip images


datagen.fit(x_train)

# %% [markdown]
# ## Model Definition

# %%
# Define the model 
# This is a simple CNN model with 3 Convolutional layers that are then followed by max-pooling layer.
# Finally, a dropout layer is added to avoid overfitting (it might still happen).

model = Sequential()
model.add(Conv2D(32,3,padding="same", activation="relu", input_shape=(img_size,img_size,3)))
model.add(MaxPool2D())

model.add(Conv2D(32, 3, padding="same", activation="relu"))
model.add(MaxPool2D())

model.add(Conv2D(64, 3, padding="same", activation="relu"))
model.add(MaxPool2D())
model.add(Dropout(0.4))

model.add(Flatten())
model.add(Dense(128,activation="relu"))
model.add(Dense(2, activation="softmax"))

model.summary()

# A summary of the model is going to be printed below
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 256, 256, 32)      896
#
#  max_pooling2d (MaxPooling2D  (None, 128, 128, 32)     0
#  )
#
#  conv2d_1 (Conv2D)           (None, 128, 128, 32)      9248
#
#  max_pooling2d_1 (MaxPooling  (None, 64, 64, 32)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 64, 64, 64)        18496
#
#  max_pooling2d_2 (MaxPooling  (None, 32, 32, 64)       0
#  2D)
#
#  dropout (Dropout)           (None, 32, 32, 64)        0
#
#  flatten (Flatten)           (None, 65536)             0
#
#  dense (Dense)               (None, 128)               8388736
#
#  dense_1 (Dense)             (None, 2)                 258
#
# =================================================================
# Total params: 8,417,634
# Trainable params: 8,417,634
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Training

# %% [markdown]
# Now we define what kind of optimizer we use for the training process. There are many different optimizers that you could choose from and you can find them here (https://keras.io/api/optimizers/). For now, I will choose the Adam optimizer. It is a stochastic gradient descent method based on adaptive estimation of first-order and second-order moments (From https://keras.io/api/optimizers/adam/).
#
# We will also have to set the learning rate (float from 0.0 - 1.0) for our stochastic gradient descent. The learning rate can be defined as the amount that the weights are updated during training per epoch. It controls how quickly the model tries to adapt to the problem. With larger learning rates the model might learn too quickly and unstable, while with smaller learning rates the model needs more epochs to finish training successfully (more info here https://machinelearningmastery.com/understand-the-dynamics-of-learning-rate-on-deep-learning-neural-networks/).
#
# Apart from the size of the data set, the learning rate and the number of epochs might be the two most important parameters for using deep learning algorithms.

# %%
# Set learning rate and epochs
lr_training = 0.0001
epochs = 50

# Set the optimizer and compile model
opt = Adam(lr_training)


# Set the loss calculation, here it is Sparse Categorical Crossentropy 
# (https://www.tensorflow.org/api_docs/python/tf/keras/losses/SparseCategoricalCrossentropy)
model.compile(
    optimizer = opt , loss = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True), 
    metrics = ['accuracy']
            )

# %%
# Check if you are using CPU and/or GPU
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 13122652847263216338
# xla_global_id: -1
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 11320098816
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 3486710321185844359
# physical_device_desc: "device: 0, name: Tesla K80, pci bus id: 0000:00:04.0, compute capability: 3.7"
# xla_global_id: 416903419
# ]

# %%
# start the training
# this step might take a while depending on the size of the data set, the number of epochs and your computational power.
history = model.fit(x_train,y_train,epochs = epochs , validation_data = (x_val, y_val))
# Out:
# Epoch 1/50
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/dispatch.py:1082: UserWarning: "`sparse_categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a sigmoid or softmax activation and thus does not represent logits. Was this intended?"
#   return dispatch_target(*args, **kwargs)
# 4/4 [==============================] - 12s 401ms/step - loss: 0.7102 - accuracy: 0.5586 - val_loss: 0.6162 - val_accuracy: 0.5641
# Epoch 2/50
# 4/4 [==============================] - 0s 113ms/step - loss: 0.5450 - accuracy: 0.8018 - val_loss: 0.4753 - val_accuracy: 0.7436
# Epoch 3/50
# 4/4 [==============================] - 0s 114ms/step - loss: 0.3631 - accuracy: 0.8739 - val_loss: 0.3087 - val_accuracy: 0.9231
# Epoch 4/50
# 4/4 [==============================] - 0s 114ms/step - loss: 0.2588 - accuracy: 0.9369 - val_loss: 0.2559 - val_accuracy: 0.9231
# Epoch 5/50
# 4/4 [==============================] - 0s 111ms/step - loss: 0.1910 - accuracy: 0.9279 - val_loss: 0.2033 - val_accuracy: 0.9231
# Epoch 6/50
# 4/4 [==============================] - 0s 116ms/step - loss: 0.1547 - accuracy: 0.9459 - val_loss: 0.1742 - val_accuracy: 0.9487
# Epoch 7/50
# 4/4 [==============================] - 0s 117ms/step - loss: 0.1202 - accuracy: 0.9640 - val_loss: 0.1578 - val_accuracy: 0.9487
# Epoch 8/50
# 4/4 [==============================] - 0s 115ms/step - loss: 0.0909 - accuracy: 0.9730 - val_loss: 0.1284 - val_accuracy: 0.9487
# Epoch 9/50
# 4/4 [==============================] - 0s 113ms/step - loss: 0.0710 - accuracy: 0.9910 - val_loss: 0.1034 - val_accuracy: 0.9487
# Epoch 10/50
# 4/4 [==============================] - 0s 115ms/step - loss: 0.0655 - accuracy: 0.9910 - val_loss: 0.0937 - val_accuracy: 0.9487
# Epoch 11/50
# 4/4 [==============================] - 0s 109ms/step - loss: 0.0459 - accuracy: 1.0000 - val_loss: 0.0890 - val_accuracy: 0.9487
# Epoch 12/50
# 4/4 [==============================] - 0s 114ms/step - loss: 0.0337 - accuracy: 1.0000 - val_loss: 0.0745 - val_accuracy: 1.0000
# Epoch 13/50
# 4/4 [==============================] - 0s 111ms/step - loss: 0.0291 - accuracy: 1.0000 - val_loss: 0.0762 - val_accuracy: 1.0000
# Epoch 14/50
# 4/4 [==============================] - 0s 111ms/step - loss: 0.0239 - accuracy: 1.0000 - val_loss: 0.0734 - val_accuracy: 1.0000
# Epoch 15/50
# 4/4 [==============================] - 0s 114ms/step - loss: 0.0181 - accuracy: 1.0000 - val_loss: 0.0702 - val_accuracy: 0.9744
# Epoch 16/50
# 4/4 [==============================] - 0s 116ms/step - loss: 0.0182 - accuracy: 1.0000 - val_loss: 0.0695 - val_accuracy: 1.0000
# Epoch 17/50
# 4/4 [==============================] - 1s 141ms/step - loss: 0.0152 - accuracy: 1.0000 - val_loss: 0.0767 - val_accuracy: 0.9487
# Epoch 18/50
# 4/4 [==============================] - 0s 113ms/step - loss: 0.0122 - accuracy: 1.0000 - val_loss: 0.0689 - val_accuracy: 0.9487
# Epoch 19/50
# 4/4 [==============================] - 0s 117ms/step - loss: 0.0106 - accuracy: 1.0000 - val_loss: 0.0647 - val_accuracy: 1.0000
# Epoch 20/50
# 4/4 [==============================] - 0s 114ms/step - loss: 0.0093 - accuracy: 1.0000 - val_loss: 0.0610 - val_accuracy: 1.0000
# Epoch 21/50
# 4/4 [==============================] - 0s 114ms/step - loss: 0.0079 - accuracy: 1.0000 - val_loss: 0.0547 - val_accuracy: 1.0000
# Epoch 22/50
# 4/4 [==============================] - 0s 112ms/step - loss: 0.0063 - accuracy: 1.0000 - val_loss: 0.0542 - val_accuracy: 1.0000
# Epoch 23/50
# 4/4 [==============================] - 0s 117ms/step - loss: 0.0077 - accuracy: 1.0000 - val_loss: 0.0589 - val_accuracy: 1.0000
# Epoch 24/50
# 4/4 [==============================] - 0s 111ms/step - loss: 0.0052 - accuracy: 1.0000 - val_loss: 0.0547 - val_accuracy: 1.0000
# Epoch 25/50
# 4/4 [==============================] - 0s 107ms/step - loss: 0.0047 - accuracy: 1.0000 - val_loss: 0.0544 - val_accuracy: 1.0000
# Epoch 26/50
# 4/4 [==============================] - 0s 111ms/step - loss: 0.0037 - accuracy: 1.0000 - val_loss: 0.0546 - val_accuracy: 1.0000
# Epoch 27/50
# 4/4 [==============================] - 0s 111ms/step - loss: 0.0039 - accuracy: 1.0000 - val_loss: 0.0547 - val_accuracy: 1.0000
# Epoch 28/50
# 4/4 [==============================] - 0s 113ms/step - loss: 0.0032 - accuracy: 1.0000 - val_loss: 0.0535 - val_accuracy: 1.0000
# Epoch 29/50
# 4/4 [==============================] - 0s 112ms/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 0.0533 - val_accuracy: 1.0000
# Epoch 30/50
# 4/4 [==============================] - 0s 116ms/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.0514 - val_accuracy: 1.0000
# Epoch 31/50
# 4/4 [==============================] - 0s 111ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.0503 - val_accuracy: 1.0000
# Epoch 32/50
# 4/4 [==============================] - 0s 111ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.0521 - val_accuracy: 1.0000
# Epoch 33/50
# 4/4 [==============================] - 0s 113ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.0491 - val_accuracy: 1.0000
# Epoch 34/50
# 4/4 [==============================] - 0s 111ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.0486 - val_accuracy: 1.0000
# Epoch 35/50
# 4/4 [==============================] - 0s 113ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.0480 - val_accuracy: 1.0000
# Epoch 36/50
# 4/4 [==============================] - 0s 114ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.0484 - val_accuracy: 1.0000
# Epoch 37/50
# 4/4 [==============================] - 0s 110ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.0484 - val_accuracy: 1.0000
# Epoch 38/50
# 4/4 [==============================] - 0s 113ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.0500 - val_accuracy: 1.0000
# Epoch 39/50
# 4/4 [==============================] - 0s 113ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.0510 - val_accuracy: 0.9744
# Epoch 40/50
# 4/4 [==============================] - 0s 117ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0479 - val_accuracy: 1.0000
# Epoch 41/50
# 4/4 [==============================] - 0s 112ms/step - loss: 9.7190e-04 - accuracy: 1.0000 - val_loss: 0.0480 - val_accuracy: 1.0000
# Epoch 42/50
# 4/4 [==============================] - 0s 110ms/step - loss: 9.4440e-04 - accuracy: 1.0000 - val_loss: 0.0478 - val_accuracy: 1.0000
# Epoch 43/50
# 4/4 [==============================] - 0s 117ms/step - loss: 8.7662e-04 - accuracy: 1.0000 - val_loss: 0.0478 - val_accuracy: 1.0000
# Epoch 44/50
# 4/4 [==============================] - 0s 113ms/step - loss: 7.1753e-04 - accuracy: 1.0000 - val_loss: 0.0467 - val_accuracy: 1.0000
# Epoch 45/50
# 4/4 [==============================] - 0s 113ms/step - loss: 6.8310e-04 - accuracy: 1.0000 - val_loss: 0.0451 - val_accuracy: 1.0000
# Epoch 46/50
# 4/4 [==============================] - 0s 113ms/step - loss: 6.6755e-04 - accuracy: 1.0000 - val_loss: 0.0432 - val_accuracy: 1.0000
# Epoch 47/50
# 4/4 [==============================] - 0s 112ms/step - loss: 6.5139e-04 - accuracy: 1.0000 - val_loss: 0.0423 - val_accuracy: 1.0000
# Epoch 48/50
# 4/4 [==============================] - 0s 112ms/step - loss: 6.0483e-04 - accuracy: 1.0000 - val_loss: 0.0419 - val_accuracy: 1.0000
# Epoch 49/50
# 4/4 [==============================] - 0s 114ms/step - loss: 6.2490e-04 - accuracy: 1.0000 - val_loss: 0.0413 - val_accuracy: 1.0000
# Epoch 50/50
# 4/4 [==============================] - 0s 109ms/step - loss: 5.2267e-04 - accuracy: 1.0000 - val_loss: 0.0416 - val_accuracy: 1.0000

# %% [markdown]
# ### Explanation of training metrices
#
# - Loss: Measures the difference between raw prediction (float) and class (0, 1)
# - Accuracy: Measures the difference between thresholded prediction (0, 1) and class (0, 1)
#
# Here, we differentiate between train loss/accuracy and val loss/accuracy. Both are calculated very similarly, but only the train loss/accuracy is taken into account when training the model, while the val loss/accuracy is only there for us to observe and is not participating in changing any weights in the model.
#
# Below we plot the accuracy and the loss.

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

# Epochs as variable
epochs_range = range(epochs)

plt.figure(figsize=(15, 15))
plt.subplot(2, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(2, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# If you want to review good/bad learning curves with over/underfitting, you can do this here (https://machinelearningmastery.com/learning-curves-for-diagnosing-machine-learning-model-performance/).
#
# Sometimes, it is not perfectly clear, whether under/overfitting is actually really bad for the problem we want to solve. Intuitively, we would think, that the validation loss and the validation accuracy are inversely correlated, but sometimes this is not the case. In a case where images with borderline predictions are getting predicted better and their output class changes (beach image is being predicted from 0.4 to 0.6) the loss decreases, while the accuracy increases. However, in a case where an image with a very bad prediction changes from 0.2 to 0.1 (the prediction is a beach but it is actually a forest), the loss decreases further, while the accuracy actually stays the same.
#
# In a perfect world, the loss will decrease and the accuracy increase. If both increase, we can say that the network will start to overfit and both cases will happen at the same time. This means that features are learned that are good for the training data set and not so great for generalization/the validation data set. This will then lead to case 2. However, at the same time the network is still learning useful patterns leading to case 1.
#
# Long story short, overfitting may be considered bad, but whether we should stop training if the network learns bad patterns even though it is continuing to learn good patterns is difficult to answer.
#
# If you observe, that your loss/accuracy curves look really bad, consider changing your dataset size, epochs or learning rate.
#
# Below, we will also calculate the F1-score, more info is to be found here (https://towardsdatascience.com/metrics-to-evaluate-your-machine-learning-algorithm-f10ba6e38234).

# %%
# Get F1-score
predictions = np.argmax(model.predict(x_val), axis=-1)
predictions = predictions.reshape(1,-1)[0]
print(classification_report(y_val, predictions, target_names = [classes[0] + ' (Class 0)',classes[1] + ' (Class 1)']))
# Out:
#                   precision    recall  f1-score   support
#
#  beach (Class 0)       1.00      1.00      1.00        20
# forest (Class 1)       1.00      1.00      1.00        19
#
#         accuracy                           1.00        39
#        macro avg       1.00      1.00      1.00        39
#     weighted avg       1.00      1.00      1.00        39

# %% [markdown]
# # Inference
#
# Next, the previously trained model makes a prediction based on what it has learned from the data on new, unseen inference data.

# %%
# Define test path
inf_path = HOME + 'Inf/'

# Get list of all inference files available
inference_files = [os.path.join(root, name)
                  for root, dirs, files in os.walk(inf_path)
                  for name in files]

# %%
# Select random image
rdm_img = random.choice(inference_files)
image_size = (img_size,img_size)

# Predict on random image
img = keras.preprocessing.image.load_img(
    rdm_img, target_size=image_size
    )
img_array = keras.preprocessing.image.img_to_array(img)
img_array = tf.expand_dims(img_array, 0)
predictions = model.predict(img_array)

# Get score for prediciton
score = predictions[0]

# Print results and show image
print(rdm_img)
print(
    'This image is %.1f percent %s and %.1f percent %s.'
    %(score[0] * 100, classes[0], score[1] * 100, classes[1]))

Image(filename=rdm_img)
# Out:
# /content/own_image_data/Inf/beach/24.es-trenc-beach-mallorca-1.jpg
# This image is 100.0 percent beach and 0.0 percent forest.

# %%
# Save model
model_save_path = HOME + 'models/beach_forest_50epoch'
model.save(model_save_path)
# Out:
# INFO:tensorflow:Assets written to: /content/own_image_data/models/beach_forest_50epoch/assets

# %% [markdown]
# # Transfer learning
#
# If we do not have a lot of training data, we might try transfer learning instead. Here, we use an already trained network, freeze certain lower layers (base model) and re-train the upper layers with our data. We might get an increase in performance without having to increase the size of our dataset.
#
# I will be creating the base model based on the MobileNetV2 model (https://arxiv.org/abs/1801.04381). It was pre-trained on the ImageNet dataset with millions of images and thousands of classes.

# %%
# It will return an error, because we are using a non-default image size.
base_model = tf.keras.applications.MobileNetV2(input_shape = (img_size, img_size, 3), include_top = False, weights = "imagenet")
# Freeze base model
base_model.trainable = False
# Out:
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.

# %%
model = tf.keras.Sequential([base_model,
                                 tf.keras.layers.GlobalAveragePooling2D(),
                                 tf.keras.layers.Dropout(0.2),
                                 tf.keras.layers.Dense(2, activation="softmax")                                     
                                ])

# %%
# Set learning rate and epochs
lr_transfer = 0.0001
epochs = 50
model.compile(optimizer=tf.keras.optimizers.Adam(lr=lr_transfer),
               loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# Train
history = model.fit(x_train,y_train,epochs = epochs , validation_data = (x_val, y_val))
# Out:
# Epoch 1/50
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# 4/4 [==============================] - 7s 777ms/step - loss: 1.1002 - accuracy: 0.2883 - val_loss: 0.9903 - val_accuracy: 0.2051
# Epoch 2/50
# 4/4 [==============================] - 1s 142ms/step - loss: 1.0263 - accuracy: 0.3423 - val_loss: 0.9289 - val_accuracy: 0.2821
# Epoch 3/50
# 4/4 [==============================] - 1s 139ms/step - loss: 0.8703 - accuracy: 0.4144 - val_loss: 0.8731 - val_accuracy: 0.3077
# Epoch 4/50
# 4/4 [==============================] - 1s 140ms/step - loss: 0.9033 - accuracy: 0.3514 - val_loss: 0.8211 - val_accuracy: 0.3846
# Epoch 5/50
# 4/4 [==============================] - 1s 141ms/step - loss: 0.8425 - accuracy: 0.3874 - val_loss: 0.7724 - val_accuracy: 0.4359
# Epoch 6/50
# 4/4 [==============================] - 1s 145ms/step - loss: 0.7898 - accuracy: 0.4865 - val_loss: 0.7273 - val_accuracy: 0.5128
# Epoch 7/50
# 4/4 [==============================] - 1s 142ms/step - loss: 0.7746 - accuracy: 0.5405 - val_loss: 0.6844 - val_accuracy: 0.5385
# Epoch 8/50
# 4/4 [==============================] - 1s 141ms/step - loss: 0.6683 - accuracy: 0.6126 - val_loss: 0.6446 - val_accuracy: 0.5897
# Epoch 9/50
# 4/4 [==============================] - 1s 142ms/step - loss: 0.6825 - accuracy: 0.5766 - val_loss: 0.6074 - val_accuracy: 0.5897
# Epoch 10/50
# 4/4 [==============================] - 1s 147ms/step - loss: 0.6313 - accuracy: 0.5856 - val_loss: 0.5729 - val_accuracy: 0.5897
# Epoch 11/50
# 4/4 [==============================] - 1s 140ms/step - loss: 0.6241 - accuracy: 0.6667 - val_loss: 0.5410 - val_accuracy: 0.7179
# Epoch 12/50
# 4/4 [==============================] - 1s 142ms/step - loss: 0.6418 - accuracy: 0.6486 - val_loss: 0.5109 - val_accuracy: 0.7692
# Epoch 13/50
# 4/4 [==============================] - 1s 142ms/step - loss: 0.5166 - accuracy: 0.7838 - val_loss: 0.4832 - val_accuracy: 0.7949
# Epoch 14/50
# 4/4 [==============================] - 1s 142ms/step - loss: 0.5101 - accuracy: 0.7658 - val_loss: 0.4580 - val_accuracy: 0.8205
# Epoch 15/50
# 4/4 [==============================] - 1s 144ms/step - loss: 0.4767 - accuracy: 0.7838 - val_loss: 0.4342 - val_accuracy: 0.8974
# Epoch 16/50
# 4/4 [==============================] - 1s 141ms/step - loss: 0.4682 - accuracy: 0.8198 - val_loss: 0.4121 - val_accuracy: 0.8974
# Epoch 17/50
# 4/4 [==============================] - 1s 142ms/step - loss: 0.4276 - accuracy: 0.8198 - val_loss: 0.3919 - val_accuracy: 0.8974
# Epoch 18/50
# 4/4 [==============================] - 1s 141ms/step - loss: 0.4377 - accuracy: 0.8018 - val_loss: 0.3729 - val_accuracy: 0.9231
# Epoch 19/50
# 4/4 [==============================] - 1s 141ms/step - loss: 0.4340 - accuracy: 0.7928 - val_loss: 0.3554 - val_accuracy: 0.9487
# Epoch 20/50
# 4/4 [==============================] - 1s 140ms/step - loss: 0.4108 - accuracy: 0.8378 - val_loss: 0.3393 - val_accuracy: 0.9744
# Epoch 21/50
# 4/4 [==============================] - 1s 146ms/step - loss: 0.3601 - accuracy: 0.8919 - val_loss: 0.3242 - val_accuracy: 0.9744
# Epoch 22/50
# 4/4 [==============================] - 1s 168ms/step - loss: 0.3354 - accuracy: 0.9009 - val_loss: 0.3103 - val_accuracy: 0.9744
# Epoch 23/50
# 4/4 [==============================] - 1s 139ms/step - loss: 0.3387 - accuracy: 0.9009 - val_loss: 0.2975 - val_accuracy: 0.9744
# Epoch 24/50
# 4/4 [==============================] - 1s 141ms/step - loss: 0.3428 - accuracy: 0.8649 - val_loss: 0.2855 - val_accuracy: 0.9744
# Epoch 25/50
# 4/4 [==============================] - 1s 138ms/step - loss: 0.3045 - accuracy: 0.9279 - val_loss: 0.2739 - val_accuracy: 0.9744
# Epoch 26/50
# 4/4 [==============================] - 1s 141ms/step - loss: 0.2938 - accuracy: 0.9189 - val_loss: 0.2632 - val_accuracy: 0.9744
# Epoch 27/50
# 4/4 [==============================] - 1s 147ms/step - loss: 0.2826 - accuracy: 0.9189 - val_loss: 0.2535 - val_accuracy: 0.9744
# Epoch 28/50
# 4/4 [==============================] - 1s 140ms/step - loss: 0.3050 - accuracy: 0.8829 - val_loss: 0.2443 - val_accuracy: 0.9744
# Epoch 29/50
# 4/4 [==============================] - 1s 142ms/step - loss: 0.2778 - accuracy: 0.9189 - val_loss: 0.2354 - val_accuracy: 0.9744
# Epoch 30/50
# 4/4 [==============================] - 1s 140ms/step - loss: 0.2736 - accuracy: 0.9189 - val_loss: 0.2270 - val_accuracy: 0.9744
# Epoch 31/50
# 4/4 [==============================] - 1s 142ms/step - loss: 0.2561 - accuracy: 0.9279 - val_loss: 0.2190 - val_accuracy: 0.9744
# Epoch 32/50
# 4/4 [==============================] - 1s 148ms/step - loss: 0.2512 - accuracy: 0.9279 - val_loss: 0.2116 - val_accuracy: 0.9744
# Epoch 33/50
# 4/4 [==============================] - 1s 142ms/step - loss: 0.2454 - accuracy: 0.9550 - val_loss: 0.2046 - val_accuracy: 0.9744
# Epoch 34/50
# 4/4 [==============================] - 1s 139ms/step - loss: 0.2305 - accuracy: 0.9459 - val_loss: 0.1981 - val_accuracy: 0.9744
# Epoch 35/50
# 4/4 [==============================] - 1s 148ms/step - loss: 0.2324 - accuracy: 0.9459 - val_loss: 0.1919 - val_accuracy: 0.9744
# Epoch 36/50
# 4/4 [==============================] - 1s 141ms/step - loss: 0.2191 - accuracy: 0.9459 - val_loss: 0.1861 - val_accuracy: 0.9744
# Epoch 37/50
# 4/4 [==============================] - 1s 142ms/step - loss: 0.2149 - accuracy: 0.9550 - val_loss: 0.1806 - val_accuracy: 0.9744
# Epoch 38/50
# 4/4 [==============================] - 1s 141ms/step - loss: 0.2106 - accuracy: 0.9369 - val_loss: 0.1755 - val_accuracy: 0.9744
# Epoch 39/50
# 4/4 [==============================] - 1s 141ms/step - loss: 0.2139 - accuracy: 0.9640 - val_loss: 0.1706 - val_accuracy: 0.9744
# Epoch 40/50
# 4/4 [==============================] - 1s 142ms/step - loss: 0.1937 - accuracy: 0.9459 - val_loss: 0.1659 - val_accuracy: 0.9744
# Epoch 41/50
# 4/4 [==============================] - 1s 163ms/step - loss: 0.1872 - accuracy: 0.9640 - val_loss: 0.1616 - val_accuracy: 0.9744
# Epoch 42/50
# 4/4 [==============================] - 1s 144ms/step - loss: 0.1791 - accuracy: 0.9730 - val_loss: 0.1572 - val_accuracy: 0.9744
# Epoch 43/50
# 4/4 [==============================] - 1s 144ms/step - loss: 0.1879 - accuracy: 0.9640 - val_loss: 0.1529 - val_accuracy: 0.9744
# Epoch 44/50
# 4/4 [==============================] - 1s 140ms/step - loss: 0.1664 - accuracy: 0.9820 - val_loss: 0.1491 - val_accuracy: 0.9744
# Epoch 45/50
# 4/4 [==============================] - 1s 143ms/step - loss: 0.1770 - accuracy: 0.9459 - val_loss: 0.1455 - val_accuracy: 0.9744
# Epoch 46/50
# 4/4 [==============================] - 1s 142ms/step - loss: 0.1849 - accuracy: 0.9550 - val_loss: 0.1421 - val_accuracy: 0.9744
# Epoch 47/50
# 4/4 [==============================] - 1s 141ms/step - loss: 0.1554 - accuracy: 0.9730 - val_loss: 0.1388 - val_accuracy: 0.9744
# Epoch 48/50
# 4/4 [==============================] - 1s 139ms/step - loss: 0.1521 - accuracy: 0.9820 - val_loss: 0.1357 - val_accuracy: 0.9744
# Epoch 49/50
# 4/4 [==============================] - 1s 144ms/step - loss: 0.1417 - accuracy: 0.9820 - val_loss: 0.1328 - val_accuracy: 0.9744
# Epoch 50/50
# 4/4 [==============================] - 1s 140ms/step - loss: 0.1485 - accuracy: 0.9550 - val_loss: 0.1299 - val_accuracy: 0.9744

# %% [markdown]
# ### Visualization of training and validation curves of transfer learning

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs_range = range(epochs)

plt.figure(figsize=(15, 15))
plt.subplot(2, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(2, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# Here we can see, that the training process shows most likely underfitting. We could now increase the learning rate and/or epochs.

# %% [markdown]
# ## Inference on transfer learning

# %%
# Pick random image from the inference folder
rdm_img = random.choice(inference_files)
image_size = (img_size,img_size)

# Predict
img = keras.preprocessing.image.load_img(
    rdm_img, target_size=image_size
    )
img_array = keras.preprocessing.image.img_to_array(img)
img_array = tf.expand_dims(img_array, 0)
predictions = model.predict(img_array)

# Get score
score = predictions[0]
print(
    'This image is %.1f percent %s and %.1f percent %s.'
    %(score[0] * 100, classes[0], score[1] * 100, classes[1]))
Image(filename=rdm_img)
# Out:
# This image is 69.2 percent beach and 30.8 percent forest.

# %%
# Save model
model_save_path = HOME + 'models/beachforest_50epo_transfer'
model.save(model_save_path)
# Out:
# WARNING:absl:Function `_wrapped_model` contains input name(s) mobilenetv2_1.00_224_input with unsupported characters which will be renamed to mobilenetv2_1_00_224_input in the SavedModel.
# INFO:tensorflow:Assets written to: /content/own_image_data/models/beachforest_50epo_transfer/assets
# INFO:tensorflow:Assets written to: /content/own_image_data/models/beachforest_50epo_transfer/assets

# %%
# Copy models back to Google drive
# !cp -r /content/own_image_data/models/ /content/drive/MyDrive/beach_forest_models/

# %% [markdown]
# ## References
#
# - https://keras.io/examples/vision/image_classification_from_scratch/
# - https://www.analyticsvidhya.com/blog/2020/10/create-image-classification-model-python-keras/
