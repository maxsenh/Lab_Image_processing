# %% [markdown]
# ## Requirements

# %% [markdown]
#  ```bash
#  conda create --name keras_dl
#  conda activate keras_dl
#  conda install -c anaconda ipykernel
#  python -m ipykernel install --user --name=firstEnv
#  https://phoenixnap.com/kb/how-to-install-keras-on-linux
#  ```

# %%
from google_images_download import google_images_download
import os

# %%
response = google_images_download.googleimagesdownload()

HOME = './Data/'
import shutil

# %%
def download_images(home_folder, dict_folder, classes):
    # Make folder structure
    n_images = sum([dict_folder[label] for label in dict_folder])
    print(n_images)
    for label in classes:
        arguments = {
                    "keywords":label,"limit":n_images,"print_urls":False,
                    "size":"large",
                    "output_directory":home_folder
                    }   #creating list of arguments
        paths = response.download(arguments)   #passing the arguments to the function
        
        
        for folder in dict_folder:
            img_per_set = dict_folder[folder]
            output_folder = home_folder + folder + '/' + label
            
            if not os.path.exists(output_folder):
                os.makedirs(output_folder)
                
            all_files = os.listdir(home_folder + label)
            for index, file in enumerate(all_files):
                if index < img_per_set:

                    if file.endswith('webp'):
                        file2 = file[:-5]
                        shutil.move(
                            home_folder + label + '/' + file,
                            output_folder + '/' + file2
                                    )
                    else:
                        shutil.move(
                        home_folder + label + '/' + file,
                        output_folder + '/' + file
                                    )
                all_files = os.listdir(home_folder + label)

# %%
# make dict
dict_folders = {'Train':30, 'Val':10, 'Inf':5}
classes = ['fire', 'ice']
download_images(HOME, dict_folders, classes)
# Out:
# 45
#
# Item no.: 1 --> Item name = fire
# Evaluating...
# Starting Download...
# Completed Image ====> 1.730cbf2e2455c64c961be8e18e793f6b_3-things-a-fire-needs-2000-c-90.jpg
# Completed Image ====> 2.shutterstock_1159272958.jpg
# Completed Image ====> 3.fire.jpg
# Completed Image ====> 4.ap_20232126020843-1363bace6efa9703c402b6d423e7c846fd19d870.jpg
# Completed Image ====> 5.flame_forhomepage_vert.jpg
# Completed Image ====> 6.istockflukesamed.jpg
# Completed Image ====> 7.1*qwkgi3ddtsnam1jnb8pvma.jpeg
# Completed Image ====> 8.cropped-img_3107-scaled-1.jpg
# Completed Image ====> 9.fire-house-structure-blaze.png
# Completed Image ====> 10.burning-emergency-fire-1749-1.jpg
# Completed Image ====> 11.110618-fire-flames-adobestock_134229099.jpeg;w=1200;h=800;mode=crop.jpg
# Completed Image ====> 12.onnbjeehpbgipdi2elvkqbo4qm.jpg.webp
# Completed Image ====> 13.3npt7vlopvouhoqgq4fbwahpiu.jpg
# Completed Image ====> 14.camp-fire.jpeg
# Completed Image ====> 15.c557ab50-6194-4b44-b3ba-e14504150efc-fire.jpg
# Completed Image ====> 16.home-page-slide-e1619460496435.jpg
# Completed Image ====> 17.bobcat_fire_los_angeles_san_gabriel_mountains-1-scaled.jpg
# Completed Image ====> 18.ahojui56qbfrlad7m4qm5pbele.png.webp
# Completed Image ====> 19.fire.jpg
# Completed Image ====> 20.hk7yw6v3bjc6hbctetif47ukou.png.webp
# Completed Image ====> 21.gettyimages-1084304680-e1571857502328.jpg
# Completed Image ====> 22.fire-generic_36106981_ver1.0.jpg
# Completed Image ====> 23.file-20200116-181629-1xtqhv8.jpg
# Completed Image ====> 24.fire-getty.jpg
# Completed Image ====> 25.jwd2913-fd-images_1920x12002.jpg.aspx.jpg
# Completed Image ====> 43.sea%20ice2.jpg
# Completed Image ====> 44.arktis_nordiska_kjoptebilder_ca_04_isfjell_clyde_river_canada_0.jpg
# Completed Image ====> 45.ice-cubes-6-1-e1592213311523.jpg
#
# Errors: 1
#
# ./Data/ice/12.underthinice_1920.jpg.webp
# ./Data/Train/ice/12.underthinice_1920.jpg

# %% [markdown]
# ## Import everything for the image classificaiton

# %%
import matplotlib.pyplot as plt
import seaborn as sns

import keras
from keras.models import Sequential
from keras.layers import Dense, Conv2D , MaxPool2D , Flatten , Dropout 
from keras.preprocessing.image import ImageDataGenerator
from keras.optimizers import Adam

from sklearn.metrics import classification_report,confusion_matrix

import tensorflow as tf

import cv2
import os

import numpy as np

# %%
img_size = 256
# set the epochs
epochs = 50

def get_data(data_dir, classes):
    data = [] 
    for label in classes: 
        path = os.path.join(data_dir, label)
        class_num = classes.index(label)
        for img in os.listdir(path):
            try:
                img_arr = cv2.imread(os.path.join(path, img))[...,::-1] #convert BGR to RGB format
                resized_arr = cv2.resize(img_arr, (img_size, img_size)) # Reshaping images to preferred size
                data.append([resized_arr, class_num])
            except Exception as e:
                print(e)
    return np.array(data, dtype=object)

# %%
train = get_data(HOME + 'Train/', classes)
val = get_data(HOME + 'Val/', classes)

# %%
l = []
for i in train:
    if(i[1] == 0):
        l.append("beach")
    else:
        l.append("forest")
sns.set_style('darkgrid')
sns.countplot(x=l)
# Out:
# <AxesSubplot:ylabel='count'>

# %%
plt.figure(figsize = (5,5))
plt.imshow(train[1][0])
plt.title(classes[train[0][1]])
# Out:
# Text(0.5, 1.0, 'fire')

# %%
plt.figure(figsize = (5,5))
plt.imshow(train[-1][0])
plt.title(classes[train[-1][1]])
# Out:
# Text(0.5, 1.0, 'ice')

# %%
# Prepare the data

x_train = []
y_train = []
x_val = []
y_val = []

for feature, label in train:
    x_train.append(feature)
    y_train.append(label)

for feature, label in val:
    x_val.append(feature)
    y_val.append(label)

# Normalize the data
x_train = np.array(x_train) / 255
x_val = np.array(x_val) / 255

x_train.reshape(-1, img_size, img_size, 1)
y_train = np.array(y_train)

x_val.reshape(-1, img_size, img_size, 1)
y_val = np.array(y_val)

# %%
# data augmentation
datagen = ImageDataGenerator(
        featurewise_center=False,  # set input mean to 0 over the dataset
        samplewise_center=False,  # set each sample mean to 0
        featurewise_std_normalization=False,  # divide inputs by std of the dataset
        samplewise_std_normalization=False,  # divide each input by its std
        zca_whitening=False,  # apply ZCA whitening
        rotation_range = 30,  # randomly rotate images in the range (degrees, 0 to 180)
        zoom_range = 0.2, # Randomly zoom image 
        width_shift_range=0.1,  # randomly shift images horizontally (fraction of total width)
        height_shift_range=0.1,  # randomly shift images vertically (fraction of total height)
        horizontal_flip = True,  # randomly flip images
        vertical_flip=False)  # randomly flip images


datagen.fit(x_train)

# %%
model = Sequential()
model.add(Conv2D(32,3,padding="same", activation="relu", input_shape=(img_size,img_size,3)))
model.add(MaxPool2D())

model.add(Conv2D(32, 3, padding="same", activation="relu"))
model.add(MaxPool2D())

model.add(Conv2D(64, 3, padding="same", activation="relu"))
model.add(MaxPool2D())
model.add(Dropout(0.4))

model.add(Flatten())
model.add(Dense(128,activation="relu"))
model.add(Dense(2, activation="softmax"))

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_3 (Conv2D)            (None, 256, 256, 32)      896
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 128, 128, 32)      0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 128, 128, 32)      9248
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 64, 64, 32)        0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 64, 64, 64)        18496
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 32, 32, 64)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 32, 32, 64)        0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 65536)             0
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               8388736
# _________________________________________________________________
# dense_3 (Dense)              (None, 2)                 258
# =================================================================
# Total params: 8,417,634
# Trainable params: 8,417,634
# Non-trainable params: 0
# _________________________________________________________________

# %%
opt = Adam(lr=0.00001)
model.compile(
    optimizer = opt , loss = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True), 
    metrics = ['accuracy']
            )

# %%
epochs = 50
history = model.fit(x_train,y_train,epochs = epochs , validation_data = (x_val, y_val))
# Out:
# Epoch 1/50
# 2/2 [==============================] - 3s 1s/step - loss: 0.6869 - accuracy: 0.5660 - val_loss: 0.6448 - val_accuracy: 0.9500
# Epoch 2/50
# 2/2 [==============================] - 2s 1s/step - loss: 0.6515 - accuracy: 0.8264 - val_loss: 0.5831 - val_accuracy: 1.0000
# Epoch 3/50
# 2/2 [==============================] - 2s 1s/step - loss: 0.6022 - accuracy: 0.9451 - val_loss: 0.5304 - val_accuracy: 1.0000
# Epoch 4/50
# 2/2 [==============================] - 2s 1s/step - loss: 0.5614 - accuracy: 0.9354 - val_loss: 0.4830 - val_accuracy: 1.0000
# Epoch 5/50
# 2/2 [==============================] - 2s 1s/step - loss: 0.5133 - accuracy: 0.9569 - val_loss: 0.4392 - val_accuracy: 1.0000
# Epoch 6/50
# 2/2 [==============================] - 2s 1s/step - loss: 0.4592 - accuracy: 0.9785 - val_loss: 0.3977 - val_accuracy: 1.0000
# Epoch 7/50
# 2/2 [==============================] - 2s 1s/step - loss: 0.4344 - accuracy: 0.9458 - val_loss: 0.3598 - val_accuracy: 1.0000
# Epoch 8/50
# 2/2 [==============================] - 2s 1s/step - loss: 0.3923 - accuracy: 0.9674 - val_loss: 0.3234 - val_accuracy: 1.0000
# Epoch 9/50
# 2/2 [==============================] - 2s 1s/step - loss: 0.3621 - accuracy: 0.9458 - val_loss: 0.2899 - val_accuracy: 1.0000
# Epoch 10/50
# 2/2 [==============================] - 2s 1s/step - loss: 0.3237 - accuracy: 0.9458 - val_loss: 0.2582 - val_accuracy: 1.0000
# Epoch 11/50
# 2/2 [==============================] - 2s 1s/step - loss: 0.2814 - accuracy: 0.9674 - val_loss: 0.2296 - val_accuracy: 1.0000
# Epoch 12/50
# 2/2 [==============================] - 3s 1s/step - loss: 0.2650 - accuracy: 0.9458 - val_loss: 0.2041 - val_accuracy: 1.0000
# Epoch 13/50
# 2/2 [==============================] - 2s 1s/step - loss: 0.2458 - accuracy: 0.9562 - val_loss: 0.1816 - val_accuracy: 1.0000
# Epoch 14/50
# 2/2 [==============================] - 2s 1s/step - loss: 0.2224 - accuracy: 0.9458 - val_loss: 0.1627 - val_accuracy: 1.0000
# Epoch 15/50
# 2/2 [==============================] - 2s 1s/step - loss: 0.1968 - accuracy: 0.9667 - val_loss: 0.1462 - val_accuracy: 1.0000
# Epoch 16/50
# 2/2 [==============================] - 2s 1s/step - loss: 0.1929 - accuracy: 0.9354 - val_loss: 0.1323 - val_accuracy: 1.0000
# Epoch 17/50
# 2/2 [==============================] - 3s 1s/step - loss: 0.1792 - accuracy: 0.9569 - val_loss: 0.1199 - val_accuracy: 1.0000
# Epoch 18/50
# 2/2 [==============================] - 2s 1s/step - loss: 0.1586 - accuracy: 0.9562 - val_loss: 0.1090 - val_accuracy: 1.0000
# Epoch 19/50
# 2/2 [==============================] - 2s 1s/step - loss: 0.1498 - accuracy: 0.9354 - val_loss: 0.1000 - val_accuracy: 1.0000
# Epoch 20/50
# 2/2 [==============================] - 2s 1s/step - loss: 0.1382 - accuracy: 0.9458 - val_loss: 0.0918 - val_accuracy: 1.0000
# Epoch 21/50
# 2/2 [==============================] - 2s 1s/step - loss: 0.1313 - accuracy: 0.9569 - val_loss: 0.0847 - val_accuracy: 1.0000
# Epoch 22/50
# 2/2 [==============================] - 2s 1s/step - loss: 0.1329 - accuracy: 0.9674 - val_loss: 0.0786 - val_accuracy: 1.0000
# Epoch 23/50
# 2/2 [==============================] - 2s 1s/step - loss: 0.1063 - accuracy: 1.0000 - val_loss: 0.0731 - val_accuracy: 1.0000
# Epoch 24/50
# 2/2 [==============================] - 2s 1s/step - loss: 0.1071 - accuracy: 0.9889 - val_loss: 0.0684 - val_accuracy: 1.0000
# Epoch 25/50
# 2/2 [==============================] - 2s 1s/step - loss: 0.1043 - accuracy: 1.0000 - val_loss: 0.0644 - val_accuracy: 1.0000
# Epoch 26/50
# 2/2 [==============================] - 2s 1s/step - loss: 0.0855 - accuracy: 0.9889 - val_loss: 0.0608 - val_accuracy: 1.0000
# Epoch 27/50
# 2/2 [==============================] - 2s 1s/step - loss: 0.0864 - accuracy: 1.0000 - val_loss: 0.0577 - val_accuracy: 1.0000
# Epoch 28/50
# 2/2 [==============================] - 2s 1s/step - loss: 0.0820 - accuracy: 1.0000 - val_loss: 0.0548 - val_accuracy: 1.0000
# Epoch 29/50
# 2/2 [==============================] - 2s 1s/step - loss: 0.0926 - accuracy: 1.0000 - val_loss: 0.0523 - val_accuracy: 1.0000
# Epoch 30/50
# 2/2 [==============================] - 2s 1s/step - loss: 0.0897 - accuracy: 1.0000 - val_loss: 0.0500 - val_accuracy: 1.0000
# Epoch 31/50
# 2/2 [==============================] - 2s 1s/step - loss: 0.0817 - accuracy: 1.0000 - val_loss: 0.0474 - val_accuracy: 1.0000
# Epoch 32/50
# 2/2 [==============================] - 2s 1s/step - loss: 0.0795 - accuracy: 1.0000 - val_loss: 0.0451 - val_accuracy: 1.0000
# Epoch 33/50
# 2/2 [==============================] - 2s 1s/step - loss: 0.0660 - accuracy: 1.0000 - val_loss: 0.0430 - val_accuracy: 1.0000
# Epoch 34/50
# 2/2 [==============================] - 2s 1s/step - loss: 0.0710 - accuracy: 1.0000 - val_loss: 0.0410 - val_accuracy: 1.0000
# Epoch 35/50
# 2/2 [==============================] - 2s 1s/step - loss: 0.0655 - accuracy: 1.0000 - val_loss: 0.0393 - val_accuracy: 1.0000
# Epoch 36/50
# 2/2 [==============================] - 2s 1s/step - loss: 0.0693 - accuracy: 1.0000 - val_loss: 0.0378 - val_accuracy: 1.0000
# Epoch 37/50
# 2/2 [==============================] - 2s 1s/step - loss: 0.0670 - accuracy: 1.0000 - val_loss: 0.0364 - val_accuracy: 1.0000
# Epoch 38/50
# 2/2 [==============================] - 2s 1s/step - loss: 0.0636 - accuracy: 1.0000 - val_loss: 0.0351 - val_accuracy: 1.0000
# Epoch 39/50
# 2/2 [==============================] - 2s 1s/step - loss: 0.0538 - accuracy: 1.0000 - val_loss: 0.0338 - val_accuracy: 1.0000
# Epoch 40/50
# 2/2 [==============================] - 2s 1s/step - loss: 0.0579 - accuracy: 1.0000 - val_loss: 0.0328 - val_accuracy: 1.0000
# Epoch 41/50
# 2/2 [==============================] - 2s 1s/step - loss: 0.0595 - accuracy: 1.0000 - val_loss: 0.0319 - val_accuracy: 1.0000
# Epoch 42/50
# 2/2 [==============================] - 2s 1s/step - loss: 0.0599 - accuracy: 1.0000 - val_loss: 0.0309 - val_accuracy: 1.0000
# Epoch 43/50
# 2/2 [==============================] - 3s 1s/step - loss: 0.0537 - accuracy: 1.0000 - val_loss: 0.0300 - val_accuracy: 1.0000
# Epoch 44/50
# 2/2 [==============================] - 2s 1s/step - loss: 0.0473 - accuracy: 1.0000 - val_loss: 0.0292 - val_accuracy: 1.0000
# Epoch 45/50
# 2/2 [==============================] - 2s 1s/step - loss: 0.0532 - accuracy: 1.0000 - val_loss: 0.0285 - val_accuracy: 1.0000
# Epoch 46/50
# 2/2 [==============================] - 2s 1s/step - loss: 0.0503 - accuracy: 1.0000 - val_loss: 0.0277 - val_accuracy: 1.0000
# Epoch 47/50
# 2/2 [==============================] - 2s 1s/step - loss: 0.0494 - accuracy: 1.0000 - val_loss: 0.0267 - val_accuracy: 1.0000
# Epoch 48/50
# 2/2 [==============================] - 2s 1s/step - loss: 0.0423 - accuracy: 1.0000 - val_loss: 0.0258 - val_accuracy: 1.0000
# Epoch 49/50
# 2/2 [==============================] - 2s 1s/step - loss: 0.0431 - accuracy: 1.0000 - val_loss: 0.0249 - val_accuracy: 1.0000
# Epoch 50/50
# 2/2 [==============================] - 2s 1s/step - loss: 0.0395 - accuracy: 1.0000 - val_loss: 0.0241 - val_accuracy: 1.0000

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

# epochs as variable
epochs_range = range(50)

plt.figure(figsize=(15, 15))
plt.subplot(2, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(2, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
predictions = np.argmax(model.predict(x_val), axis=-1)
predictions = predictions.reshape(1,-1)[0]
print(classification_report(y_val, predictions, target_names = ['beach (Class 0)','forest (Class 1)']))
# Out:
#                   precision    recall  f1-score   support
#
#  beach (Class 0)       1.00      1.00      1.00        10
# forest (Class 1)       1.00      1.00      1.00        10
#
#         accuracy                           1.00        20
#        macro avg       1.00      1.00      1.00        20
#     weighted avg       1.00      1.00      1.00        20

# %% [markdown]
# # Inference

# %%
import random
from IPython.display import display, Image

path = HOME + 'Inf/'

inference_files = [os.path.join(root, name)
                  for root, dirs, files in os.walk(path)
                  for name in files]

# %%
rdm_img = random.choice(inference_files)

image_size = (256,256)


print(rdm_img)

img = keras.preprocessing.image.load_img(
    rdm_img, target_size=image_size
    )
img_array = keras.preprocessing.image.img_to_array(img)
img_array = tf.expand_dims(img_array, 0)

predictions = model.predict(img_array)
score = predictions[0]
print(
    'This image is %.1f percent %s and %.1f percent %s.'
    %(score[0] * 100, classes[0], score[1] * 100, classes[1]))
Image(filename=rdm_img)
# Out:
# ./Data/Inf/fire/35.o4xsx3fhdbb7jiuc4ypf7h4udy.jpg
# This image is 100.0 percent fire and 0.0 percent ice.

# %% [markdown]
# # Transfer learning

# %%
base_model = tf.keras.applications.MobileNetV2(input_shape = (256, 256, 3), include_top = False, weights = "imagenet")
# Out:
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_224_no_top.h5
# 9412608/9406464 [==============================] - 1s 0us/step

# %%
base_model.trainable = False

# %%
model = tf.keras.Sequential([base_model,
                                 tf.keras.layers.GlobalAveragePooling2D(),
                                 tf.keras.layers.Dropout(0.2),
                                 tf.keras.layers.Dense(2, activation="softmax")                                     
                                ])
epochs = 50

# %%
base_learning_rate = 0.00001
model.compile(optimizer=tf.keras.optimizers.Adam(lr=base_learning_rate),
               loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

history = model.fit(x_train,y_train,epochs = 100 , validation_data = (x_val, y_val))
# Out:
# Epoch 1/100
# 2/2 [==============================] - 4s 2s/step - loss: 1.0450 - accuracy: 0.4347 - val_loss: 1.0014 - val_accuracy: 0.4000
# Epoch 2/100
# 2/2 [==============================] - 2s 963ms/step - loss: 1.0293 - accuracy: 0.4028 - val_loss: 0.9994 - val_accuracy: 0.4000
# Epoch 3/100
# 2/2 [==============================] - 2s 961ms/step - loss: 1.1095 - accuracy: 0.2736 - val_loss: 0.9974 - val_accuracy: 0.4000
# Epoch 4/100
# 2/2 [==============================] - 2s 968ms/step - loss: 1.0587 - accuracy: 0.3806 - val_loss: 0.9953 - val_accuracy: 0.4000
# Epoch 5/100
# 2/2 [==============================] - 2s 950ms/step - loss: 1.0303 - accuracy: 0.3917 - val_loss: 0.9934 - val_accuracy: 0.4000
# Epoch 6/100
# 2/2 [==============================] - 2s 948ms/step - loss: 0.9710 - accuracy: 0.4562 - val_loss: 0.9914 - val_accuracy: 0.4000
# Epoch 7/100
# 2/2 [==============================] - 2s 968ms/step - loss: 1.1156 - accuracy: 0.3604 - val_loss: 0.9894 - val_accuracy: 0.4000
# Epoch 8/100
# 2/2 [==============================] - 2s 965ms/step - loss: 0.9538 - accuracy: 0.4333 - val_loss: 0.9874 - val_accuracy: 0.4000
# Epoch 9/100
# 2/2 [==============================] - 2s 953ms/step - loss: 1.0031 - accuracy: 0.3694 - val_loss: 0.9854 - val_accuracy: 0.4000
# Epoch 10/100
# 2/2 [==============================] - 2s 959ms/step - loss: 0.8562 - accuracy: 0.4458 - val_loss: 0.9834 - val_accuracy: 0.4000
# Epoch 11/100
# 2/2 [==============================] - 2s 969ms/step - loss: 0.9466 - accuracy: 0.4562 - val_loss: 0.9814 - val_accuracy: 0.4000
# Epoch 12/100
# 2/2 [==============================] - 2s 971ms/step - loss: 1.0248 - accuracy: 0.3715 - val_loss: 0.9795 - val_accuracy: 0.4000
# Epoch 13/100
100
# 2/2 [==============================] - 2s 1s/step - loss: 0.8676 - accuracy: 0.5750 - val_loss: 0.8545 - val_accuracy: 0.5500
# Epoch 83/100
# 2/2 [==============================] - 2s 992ms/step - loss: 0.8130 - accuracy: 0.4896 - val_loss: 0.8529 - val_accuracy: 0.5500
# Epoch 84/100
# 2/2 [==============================] - 2s 1s/step - loss: 0.8072 - accuracy: 0.5556 - val_loss: 0.8513 - val_accuracy: 0.5500
# Epoch 85/100
# 2/2 [==============================] - 2s 959ms/step - loss: 0.8223 - accuracy: 0.5000 - val_loss: 0.8497 - val_accuracy: 0.5500
# Epoch 86/100
# 2/2 [==============================] - 2s 995ms/step - loss: 0.8196 - accuracy: 0.5340 - val_loss: 0.8481 - val_accuracy: 0.5500
# Epoch 87/100
# 2/2 [==============================] - 2s 1s/step - loss: 0.7655 - accuracy: 0.6076 - val_loss: 0.8466 - val_accuracy: 0.5500
# Epoch 88/100
# 2/2 [==============================] - 2s 1s/step - loss: 0.8462 - accuracy: 0.5229 - val_loss: 0.8450 - val_accuracy: 0.5500
# Epoch 89/100
# 2/2 [==============================] - 2s 1s/step - loss: 0.9161 - accuracy: 0.4785 - val_loss: 0.8435 - val_accuracy: 0.5500
# Epoch 90/100
# 2/2 [==============================] - 2s 1s/step - loss: 0.8978 - accuracy: 0.5111 - val_loss: 0.8419 - val_accuracy: 0.5500
# Epoch 91/100
# 2/2 [==============================] - 2s 994ms/step - loss: 0.7113 - accuracy: 0.6299 - val_loss: 0.8404 - val_accuracy: 0.5500
# Epoch 92/100
# 2/2 [==============================] - 2s 996ms/step - loss: 0.8161 - accuracy: 0.5764 - val_loss: 0.8388 - val_accuracy: 0.5500
# Epoch 93/100
# 2/2 [==============================] - 2s 996ms/step - loss: 0.8803 - accuracy: 0.4562 - val_loss: 0.8373 - val_accuracy: 0.5500
# Epoch 94/100
# 2/2 [==============================] - 2s 998ms/step - loss: 0.7717 - accuracy: 0.5215 - val_loss: 0.8357 - val_accuracy: 0.5500
# Epoch 95/100
# 2/2 [==============================] - 2s 988ms/step - loss: 0.8134 - accuracy: 0.5868 - val_loss: 0.8342 - val_accuracy: 0.5500
# Epoch 96/100
# 2/2 [==============================] - 2s 987ms/step - loss: 0.7600 - accuracy: 0.4889 - val_loss: 0.8327 - val_accuracy: 0.5500
# Epoch 97/100
# 2/2 [==============================] - 2s 1s/step - loss: 0.8488 - accuracy: 0.5326 - val_loss: 0.8311 - val_accuracy: 0.5500
# Epoch 98/100
# 2/2 [==============================] - 2s 991ms/step - loss: 0.8703 - accuracy: 0.4903 - val_loss: 0.8296 - val_accuracy: 0.5500
# Epoch 99/100
# 2/2 [==============================] - 2s 983ms/step - loss: 0.8005 - accuracy: 0.5757 - val_loss: 0.8281 - val_accuracy: 0.5500
# Epoch 100/100
# 2/2 [==============================] - 2s 985ms/step - loss: 0.7723 - accuracy: 0.5875 - val_loss: 0.8266 - val_accuracy: 0.5500

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs_range = range(100)

plt.figure(figsize=(15, 15))
plt.subplot(2, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(2, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# # Inference on transfer learning

# %%
rdm_img = random.choice(inference_files)

image_size = (256,256)


print(rdm_img)

img = keras.preprocessing.image.load_img(
    rdm_img, target_size=image_size
    )
img_array = keras.preprocessing.image.img_to_array(img)
img_array = tf.expand_dims(img_array, 0)

predictions = model.predict(img_array)
score = predictions[0]
print(
    'This image is %.1f percent %s and %.1f percent %s.'
    %(score[0] * 100, classes[0], score[1] * 100, classes[1]))
Image(filename=rdm_img)
# Out:
# ./Data/Inf/fire/35.o4xsx3fhdbb7jiuc4ypf7h4udy.jpg
# This image is 44.9 percent fire and 55.1 percent ice.
