# %% [markdown]
# # Lab Image Processing Class
# ## Image Classification with Keras/Tensorflow

# %% [markdown]
# If you have problems with the google_images_download library,
# pip show google_images_download

# %%
# Imports

# Library allowing downloads of google images
from google_images_download import google_images_download

# Miscellaneous operating system libraries
import os
import shutil
import numpy as np
import random

# Libraries for plotting
import matplotlib.pyplot as plt
import seaborn as sns
import cv2
from IPython.display import display, Image

# Deep learning libraries Keras and Tensorflow for training and sklearn for the metrics
import keras
from keras.models import Sequential
from keras.layers import Dense, Conv2D , MaxPool2D , Flatten , Dropout 
from keras.preprocessing.image import ImageDataGenerator
from keras.optimizers import Adam
from sklearn.metrics import classification_report,confusion_matrix
import tensorflow as tf

# %% [markdown]
# ## Download images from Google
#
# Below, we will download images from Google based on the search queries we give. You can also use your own images, if you do, I recommend to have the following data structure:
#
# - Lab_image_processing (the Github repository)
#     - Image_classification.ipynb
#     - ...
# - Data
#     - Train
#         - Class 1
#         - Class 2
#     - Val
#         - Class 1
#         - Class 2
#     - Inf
#         - Class 1
#         - Class 2
# - Models
#
# If you want to download images from google, you can use the function below, it will also create the right folder structure.

# %%
# Function to download Google images
# Again, you are welcome to use your own data

def download_images(home_folder, dict_data, classes):
    
    # get response from google
    response = google_images_download.googleimagesdownload()

    # get number of total images to download
    n_images = sum([dict_data[label] for label in dict_data])
    for label in classes:
        
        # creating dictionary of arguments for downloading from google
        # all possible arguments you can find here: 
        # https://google-images-download.readthedocs.io/en/latest/arguments.html
        arguments = {
                    "keywords":label,"limit":n_images,"print_urls":False,
                    "size":"large",
                    "output_directory":home_folder
                    }   
        # passing the arguments to the function
        paths = response.download(arguments)   
        
        # create folder structure
        for one_part in dict_data:
            img_per_set = dict_data[one_part]
            output_folder = home_folder + one_part + '/' + label
            
            if not os.path.exists(output_folder):
                os.makedirs(output_folder)
                
            all_files = os.listdir(home_folder + label)
            
            # go through all downloaded files and split up the data
            # for example: total images 100
            # train:70, val:20, inf: 10
            for index, file in enumerate(all_files):
                if index < img_per_set:
                    
                    # change file name if it ends with the file extension .webp
                    if file.endswith('webp'):
                        file2 = file[:-5]
                        
                        # move files to the designated folders
                        shutil.move(
                            home_folder + label + '/' + file,
                            output_folder + '/' + file2
                                    )
                    else:
                        # move files to the designated folders
                        shutil.move(
                        home_folder + label + '/' + file,
                        output_folder + '/' + file
                                    )
                # update the list of files
                all_files = os.listdir(home_folder + label)

# %%
# define our home folder
HOME = '../Data/'
# create dictionary based on how many images we wany per set
dict_folders = {'Train':65, 'Val':20, 'Inf':15}
# define the classes
classes = ['cat', 'dog']
# pass the arguments and download the images
download_images(HOME, dict_folders, classes)
# Out:
# Item no.: 1 --> Item name = cat
# Evaluating...
# Starting Download...
# Completed Image ====> 1.1800x1200_cat_relaxing_on_patio_other.jpg.webp
# Completed Image ====> 2.5616.jpg
# Completed Image ====> 3.67586673.jpg
# Completed Image ====> 4.an_up-close_picture_of_a_curious_male_domestic_shorthair_tabby_cat.jpg
# Completed Image ====> 5.02-cat-training-nationalgeographic_1484324.jpg.webp
# Completed Image ====> 6.vsy6kjdnq2psxsczb6cvyf.jpg
# Completed Image ====> 7.how-is-a-cats-age-determined-554296-01-52252e4c987b4655a4bf14394757e54e.jpg
# Completed Image ====> 8.cat_poster_1.jpg
# Completed Image ====> 9.32665e6f-8d90-4567-9769d59e11db7f26_source.jpg
# Completed Image ====> 10.kitten-510651.jpg
# Completed Image ====> 62.cat-tales-img.width-2000.jpg
# Completed Image ====> 63.cat_1280p_0.jpg
# Completed Image ====> 64.cat-10-e1573844975155.jpg
# Completed Image ====> 65.635818943680464639-103115cute-kitty.jpg
# Completed Image ====> 66.how%20to%20spot%20and%20treat%20cat%20anxietyhero.jpg
# Completed Image ====> 67.covid-woman-cat.jpg
# Completed Image ====> 68._116210520_neo4_976.jpg
# Completed Image ====> 69.lane-cats.jpg
# Completed Image ====> 70.zoomcat.jpg
# Completed Image ====> 71.9781328489906.gif
# Completed Image ====> 72.cat-close-to-screen.jpg.webp
# Completed Image ====> 73.istock-805170532_absolutimages.jpg
# Completed Image ====> 74.ad9c393fe6cbde113fb53df8d44ca03dc950da4c.jpg
# Completed Image ====> 75.arcticcatlogo_v2.jpg
# Completed Image ====> 76.miyagi100_1.jpg
# Completed Image ====> 77.cat-age-chart-hero-opt1.jpg
# Completed Image ====> 78.hero-nuzzle_x800.jpg
# Completed Image ====> 79.small-exotic-cats.jpg
# Completed Image ====> 80.91ohn1bkstl._ac_sl1500_.jpg
# Completed Image ====> 81.5e2ef209ab49fd373f6ba714.jpg
# Completed Image ====> 82.gettyimages-827755050_wide-07e187f742daaccc3f0d88565eb29f3f26179ed7.jpg
# Completed Image ====> 83.istock-916358708.jpg
# Completed Image ====> 84.domestic-feline-tabby-cat.jpg
# Completed Image ====> 85.adopt-a-cat-or-kitten-from-rspca.jpg
# Completed Image ====> 86.screen_shot_2019_07_18_at_4.16.52_pm.png.jpg
# Completed Image ====> 87.cvf-best_mockup_01c_3000.jpg
# Completed Image ====> 88.cat_16x9.jpg
# Completed Image ====> 89.maxresdefault.jpg
# Completed Image ====> 90.grumpy_kitty....jpg
# Completed Image ====> 91.cat-410261.jpg
# Completed Image ====> 92.gettyimages-513859318.jpg
# Completed Image ====> 93.taylor-swift-cats.jpg
# Completed Image ====> 94.kit-cat.png
# Invalid image format 'image/tiff'. Skipping...
# Completed Image ====> 95.man-in-bed-cradling-cat.jpg
# Completed Image ====> 96.roaming+cat+notched+%281%29.jpg
# Completed Image ====> 97.cia-cat-530929626.jpg
# Completed Image ====> 98.imrs.php.webp
#
#
# Unfortunately all 100 could not be downloaded because some images were not downloadable. 98 is all we got for this search filter!
#
# Errors: 2
#
#
# Item no.: 1 --> Item name = dog
# Evaluating...
# Starting Download...
# Completed Image ====> 1.3408.jpg
# Completed Image ====> 2.maxresdefault.jpg
# Completed Image ====> 3.1800x1200_dog_cool_summer_other.jpg.webp
# Completed Image ====> 4.golder-retriever-puppy.jpeg
# Completed Image ====> 5.domestic-dog_thumb.jpg.webp
# Completed Image ====> 6.puppy-410265.jpg
# Completed Image ====> 7.pop_culter_dog_rank_alyceatinoyan_feature.0.jpg
# Completed Image ====> 8.image.jpg
# Completed Image ====> 9.the_science-backed_benefits_of_being_a_dog_owner.jpg
# Completed Image ====> 10.105992231-1561667465295gettyimages-521697453.jpeg
# Completed Image ====> 11.large-dog-on-walk-looking-over-hills.jpg
# Completed Image ====> 12.nova-zembla.jpg
# Completed Image ====> 13.1915.jpg
# Completed Image ====> 14.file-20200309-118956-1cqvm6j.jpg
# Completed Image ====> 60.dogfighting-167867.jpg
# Completed Image ====> 61.4--running-dogs-in-a-row-180675748-5c6461ebc9e77c00016628ad.jpg
# Completed Image ====> 62.adobestock_190562703.jpeg
# Completed Image ====> 63.1800x1200_surprises_about_dogs_and_cats_slideshow.jpg.webp
# Completed Image ====> 64.5dfe9556-8f8e-4efd-80aac879686d144b_source.jpg
# Completed Image ====> 65.heyward-jack-edit.jpg
# Completed Image ====> 66.walking-golden-retriever-962608834-a1e37cb8007a443da9afb578f14b8de0.jpg
# Completed Image ====> 67.5100.jpg
# Completed Image ====> 68.bunny_the_dog.jpg
# Completed Image ====> 69.main_puppies_1280p.jpg
# Completed Image ====> 70.dogs_spot_2.jpg
# Completed Image ====> 71.15-amazing-dog-factshero.jpg
# Invalid image format 'text/plain'. Skipping...
# Completed Image ====> 72.adopt-a-dog-or-puppy-from-rspca-south-australia.jpg
# Completed Image ====> 73.maxresdefault.jpg
# Completed Image ====> 74.7-things-blog-graphic.jpg
# Completed Image ====> 75.image-20160310-26248-1dlu2cu.jpg
# Completed Image ====> 76.01-domesticated-dog-alaska.jpg.webp
# Completed Image ====> 77.fitbark_human_dog_hug.jpg
# Completed Image ====> 78.b3-eu444_dogs_m_20190822133824.jpg
# Completed Image ====> 79.20200709-dog.jpg
# Completed Image ====> 80.use-dog-repellents-2132575-hero-01-a712e0cca5c143b1a885b15841c50de5.jpg
# Completed Image ====> 81.image.jpg
# Completed Image ====> 82.original.jpg
# Completed Image ====> 83.dog-photo-37.jpg
# Completed Image ====> 84.5f3f18938bf1a1b1d995f52d_hero-dog-insurance---rotated_optimized.png
# Invalid image format 'text/html'. Skipping...
# Completed Image ====> 85.2021-03-09t140505z_29221023_rc2q7m9lzaaa_rtrmadp_3_usa-biden-first-dogs.jpg.webp
# Completed Image ====> 86.mv5bmtg5mjcwmzy5ov5bml5banbnxkftztgwmdm0oti1njm@._v1_.jpg
# Completed Image ====> 87.1200px-johnson%27s_household_book_of_nature_%287268642682%29.jpg
# Completed Image ====> 88.34719489134_2eb736aab8_o.jpg
# Completed Image ====> 89.woofmeow-dog-image.png
# Completed Image ====> 90.latest.png
# Completed Image ====> 91.square_puppy_hope_v2.jpg
# Completed Image ====> 92.dog-day1.jpg
# Completed Image ====> 93.spiritdog3.jpg
# Completed Image ====> 94.bowie-roadtrip_h.jpg
# Completed Image ====> 95.dog-leash-aggression.jpg
# Completed Image ====> 96.120-pawsome-dog-names-that-stand-out-from-the-pack.jpg
# Completed Image ====> 97.amy-baugess-detvmzcbyia-unsplash-1593547722.jpg
# Completed Image ====> 98.210426060633-03-turkmenistan-dog-celebration.jpg
#
#
# Unfortunately all 100 could not be downloaded because some images were not downloadable. 98 is all we got for this search filter!
#
# Errors: 2

# %% [markdown]
# ## Data preparation

# %%
# function to prepare the data and save the data in memory as numpy arrays
# Important: here we are also going to resize the data, as for most networks,
# all data points have to be the same shape.

def get_data(data_dir, classes, img_size):
    data = [] 
    for label in classes: 
        path = os.path.join(data_dir, label)
        class_num = classes.index(label)
        for img in os.listdir(path):
            try:
                img_arr = cv2.imread(os.path.join(path, img))[...,::-1] #convert BGR to RGB format
                resized_arr = cv2.resize(img_arr, (img_size, img_size)) # Reshaping images to preferred size
                data.append([resized_arr, class_num])
            except Exception as e:
                print(e)
    return np.array(data, dtype=object)

# %%
# Define the target image size, the larger, the more features, but also longer training times.
# If you have a decent laptop, 256 pixels is fine.
img_size = 256

train = get_data(HOME + 'Train/', classes, img_size)
val = get_data(HOME + 'Val/', classes, img_size)

# %%
# view the data and review how many of the training images are availabe
# useful to verify that we loaded all the images from the training data set as numpy arrays
# sometimes, with faulty file endings, there might be errors
l = []
for i in train:
    if(i[1] == 0):
        l.append(classes[0])
    else:
        l.append(classes[1])
sns.set_style('darkgrid')
sns.countplot(x=l)
# Out:
# <AxesSubplot:ylabel='count'>

# %%
# show one image from the first class
plt.figure(figsize = (5,5))
plt.imshow(train[1][0])
plt.title(classes[train[0][1]])
# Out:
# Text(0.5, 1.0, 'beach')

# %%
# show one image from the second class
plt.figure(figsize = (5,5))
plt.imshow(train[-1][0])
plt.title(classes[train[-1][1]])
# Out:
# Text(0.5, 1.0, 'forest')

# %%
# Data preprocessing

x_train = []
y_train = []
x_val = []
y_val = []

for feature, label in train:
    x_train.append(feature)
    y_train.append(label)

for feature, label in val:
    x_val.append(feature)
    y_val.append(label)

# Normalize the data
x_train = np.array(x_train) / 255
x_val = np.array(x_val) / 255

x_train.reshape(-1, img_size, img_size, 1)
y_train = np.array(y_train)

x_val.reshape(-1, img_size, img_size, 1)
y_val = np.array(y_val)

# %%
# data augmentation on training data
datagen = ImageDataGenerator(
        featurewise_center=False,  # set input mean to 0 over the dataset
        samplewise_center=False,  # set each sample mean to 0
        featurewise_std_normalization=False,  # divide inputs by std of the dataset
        samplewise_std_normalization=False,  # divide each input by its std
        zca_whitening=False,  # apply ZCA whitening
        rotation_range = 30,  # randomly rotate images in the range (degrees, 0 to 180)
        zoom_range = 0.2, # Randomly zoom image 
        width_shift_range=0.1,  # randomly shift images horizontally (fraction of total width)
        height_shift_range=0.1,  # randomly shift images vertically (fraction of total height)
        horizontal_flip = True,  # randomly flip images
        vertical_flip=False)  # randomly flip images


datagen.fit(x_train)

# %% [markdown]
# ## Model Definition

# %%
# Define the model 
# This is a simple CNN model with 3 Convolutional layers that are then followed by max-pooling layer.
# Finally, a dropout layer is added to avoid overfitting (it might still happen).

model = Sequential()
model.add(Conv2D(32,3,padding="same", activation="relu", input_shape=(img_size,img_size,3)))
model.add(MaxPool2D())

model.add(Conv2D(32, 3, padding="same", activation="relu"))
model.add(MaxPool2D())

model.add(Conv2D(64, 3, padding="same", activation="relu"))
model.add(MaxPool2D())
model.add(Dropout(0.4))

model.add(Flatten())
model.add(Dense(128,activation="relu"))
model.add(Dense(2, activation="softmax"))

model.summary()

# A summary of the model is going to be printed below
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 256, 256, 32)      896
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 128, 128, 32)      0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 128, 128, 32)      9248
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 64, 64, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 64, 64, 64)        18496
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 32, 32, 64)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 32, 32, 64)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 65536)             0
# _________________________________________________________________
# dense (Dense)                (None, 128)               8388736
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 258
# =================================================================
# Total params: 8,417,634
# Trainable params: 8,417,634
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Training

# %% [markdown]
# Now we define what kind of optimizer we use for the training process. There are many different optimizers that you could choose from and you can find them here (https://keras.io/api/optimizers/). For now, I will choose the Adam optimizer. It is a stochastic gradient descent method based on adaptive estimation of first-order and second-order moments (From https://keras.io/api/optimizers/adam/).
#
# We will also have to set the learning rate (float from 0.0 - 1.0) for our stochastic gradient descent. The learning rate can be defined as the amount that the weights are updated during training per epoch. It controls how quickly the model tries to adapt to the problem. With larger learning rates the model might learn too quickly and unstable, while with smaller learning rates the model needs more epochs to finish training successfully (more info here https://machinelearningmastery.com/understand-the-dynamics-of-learning-rate-on-deep-learning-neural-networks/).
#
# Apart from the size of the data set, the learning rate and the number of epochs might be the two most important parameters for using deep learning algorithms.

# %%
# Set learning rate and epochs
lr_training = 0.0001
epochs = 50

# Set the optimizer and compile model
opt = Adam(lr_training)

# set the loss calculation, here it is Sparse Categorical Crossentropy 
# (https://www.tensorflow.org/api_docs/python/tf/keras/losses/SparseCategoricalCrossentropy)
model.compile(
    optimizer = opt , loss = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True), 
    metrics = ['accuracy']
            )

# %%
# start the training
# this step might take a while depending on the size of the data set, the number of epochs and your computational power.
history = model.fit(x_train,y_train,epochs = epochs , validation_data = (x_val, y_val))
# Out:
# Epoch 1/50
# 4/4 [==============================] - 17s 3s/step - loss: 0.6615 - accuracy: 0.5492 - val_loss: 0.4516 - val_accuracy: 0.8205
# Epoch 2/50
# 4/4 [==============================] - 13s 3s/step - loss: 0.3419 - accuracy: 0.8324 - val_loss: 0.2636 - val_accuracy: 0.8974
# Epoch 3/50
# 4/4 [==============================] - 12s 3s/step - loss: 0.2054 - accuracy: 0.9398 - val_loss: 0.2333 - val_accuracy: 0.8974
# Epoch 4/50
# 4/4 [==============================] - 13s 3s/step - loss: 0.1624 - accuracy: 0.9430 - val_loss: 0.1722 - val_accuracy: 0.9231
# Epoch 5/50
# 4/4 [==============================] - 13s 3s/step - loss: 0.1354 - accuracy: 0.9601 - val_loss: 0.2073 - val_accuracy: 0.8974
# Epoch 6/50
# 4/4 [==============================] - 13s 3s/step - loss: 0.1215 - accuracy: 0.9440 - val_loss: 0.2136 - val_accuracy: 0.8974
# Epoch 7/50
# 4/4 [==============================] - 14s 3s/step - loss: 0.0708 - accuracy: 0.9886 - val_loss: 0.1064 - val_accuracy: 0.9744
# Epoch 8/50
# 4/4 [==============================] - 12s 3s/step - loss: 0.0557 - accuracy: 0.9943 - val_loss: 0.1348 - val_accuracy: 0.8974
# Epoch 9/50
# 4/4 [==============================] - 13s 3s/step - loss: 0.0545 - accuracy: 0.9850 - val_loss: 0.0977 - val_accuracy: 0.9231
# Epoch 10/50
# 4/4 [==============================] - 14s 3s/step - loss: 0.0439 - accuracy: 0.9912 - val_loss: 0.0792 - val_accuracy: 0.9744
# Epoch 11/50
# 4/4 [==============================] - 12s 3s/step - loss: 0.0318 - accuracy: 1.0000 - val_loss: 0.1229 - val_accuracy: 0.8974
# Epoch 12/50
# 4/4 [==============================] - 11s 3s/step - loss: 0.0353 - accuracy: 0.9849 - val_loss: 0.0730 - val_accuracy: 0.9744
# Epoch 13/50
# 4/4 [==============================] - 13s 3s/step - loss: 0.0188 - accuracy: 1.0000 - val_loss: 0.0697 - val_accuracy: 0.9744
# Epoch 14/50
# 4/4 [==============================] - 13s 3s/step - loss: 0.0154 - accuracy: 1.0000 - val_loss: 0.0791 - val_accuracy: 0.9744
# Epoch 15/50
# 4/4 [==============================] - 11s 3s/step - loss: 0.0143 - accuracy: 1.0000 - val_loss: 0.0740 - val_accuracy: 0.9744
# Epoch 16/50
# 4/4 [==============================] - 11s 3s/step - loss: 0.0091 - accuracy: 1.0000 - val_loss: 0.0691 - val_accuracy: 0.9744
# Epoch 17/50
# 4/4 [==============================] - 11s 3s/step - loss: 0.0103 - accuracy: 1.0000 - val_loss: 0.0681 - val_accuracy: 0.9744
# Epoch 18/50
# 4/4 [==============================] - 11s 3s/step - loss: 0.0076 - accuracy: 1.0000 - val_loss: 0.0765 - val_accuracy: 0.9744
# Epoch 19/50
# 4/4 [==============================] - 11s 3s/step - loss: 0.0068 - accuracy: 1.0000 - val_loss: 0.0676 - val_accuracy: 0.9744
# Epoch 20/50
# 4/4 [==============================] - 11s 3s/step - loss: 0.0059 - accuracy: 1.0000 - val_loss: 0.0672 - val_accuracy: 0.9744
# Epoch 21/50
# 4/4 [==============================] - 11s 3s/step - loss: 0.0049 - accuracy: 1.0000 - val_loss: 0.0684 - val_accuracy: 0.9744
# Epoch 22/50
# 4/4 [==============================] - 11s 3s/step - loss: 0.0048 - accuracy: 1.0000 - val_loss: 0.0680 - val_accuracy: 0.9744
# Epoch 23/50
# 4/4 [==============================] - 11s 3s/step - loss: 0.0037 - accuracy: 1.0000 - val_loss: 0.0667 - val_accuracy: 0.9744
# Epoch 24/50
# 4/4 [==============================] - 11s 3s/step - loss: 0.0038 - accuracy: 1.0000 - val_loss: 0.0676 - val_accuracy: 0.9744
# Epoch 25/50
# 4/4 [==============================] - 12s 3s/step - loss: 0.0036 - accuracy: 1.0000 - val_loss: 0.0665 - val_accuracy: 0.9744
# Epoch 26/50
# 4/4 [==============================] - 13s 3s/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 0.0671 - val_accuracy: 0.9744
# Epoch 27/50
# 4/4 [==============================] - 12s 3s/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.0658 - val_accuracy: 0.9744
# Epoch 28/50
# 4/4 [==============================] - 14s 4s/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.0686 - val_accuracy: 0.9744
# Epoch 29/50
# 4/4 [==============================] - 13s 3s/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.0660 - val_accuracy: 0.9744
# Epoch 30/50
# 4/4 [==============================] - 12s 3s/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.0645 - val_accuracy: 0.9744
# Epoch 31/50
# 4/4 [==============================] - 11s 3s/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.0645 - val_accuracy: 0.9744
# Epoch 32/50
# 4/4 [==============================] - 14s 3s/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.0654 - val_accuracy: 0.9744
# Epoch 33/50
# 4/4 [==============================] - 16s 4s/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0660 - val_accuracy: 0.9744
# Epoch 34/50
# 4/4 [==============================] - 14s 3s/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0662 - val_accuracy: 0.9744
# Epoch 35/50
# 4/4 [==============================] - 16s 4s/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.0661 - val_accuracy: 0.9744
# Epoch 36/50
# 4/4 [==============================] - 12s 3s/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0664 - val_accuracy: 0.9744
# Epoch 37/50
# 4/4 [==============================] - 10s 2s/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0660 - val_accuracy: 0.9744
# Epoch 38/50
# 4/4 [==============================] - 10s 2s/step - loss: 8.5756e-04 - accuracy: 1.0000 - val_loss: 0.0659 - val_accuracy: 0.9744
# Epoch 39/50
# 4/4 [==============================] - 10s 2s/step - loss: 6.3189e-04 - accuracy: 1.0000 - val_loss: 0.0658 - val_accuracy: 0.9744
# Epoch 40/50
# 4/4 [==============================] - 10s 2s/step - loss: 7.9107e-04 - accuracy: 1.0000 - val_loss: 0.0673 - val_accuracy: 0.9744
# Epoch 41/50
# 4/4 [==============================] - 10s 2s/step - loss: 7.1505e-04 - accuracy: 1.0000 - val_loss: 0.0668 - val_accuracy: 0.9744
# Epoch 42/50
# 4/4 [==============================] - 12s 3s/step - loss: 6.3847e-04 - accuracy: 1.0000 - val_loss: 0.0655 - val_accuracy: 0.9744
# Epoch 43/50
# 4/4 [==============================] - 10s 2s/step - loss: 6.0349e-04 - accuracy: 1.0000 - val_loss: 0.0657 - val_accuracy: 0.9744
# Epoch 44/50
# 4/4 [==============================] - 13s 4s/step - loss: 6.0237e-04 - accuracy: 1.0000 - val_loss: 0.0663 - val_accuracy: 0.9744
# Epoch 45/50
# 4/4 [==============================] - 19s 5s/step - loss: 5.2719e-04 - accuracy: 1.0000 - val_loss: 0.0678 - val_accuracy: 0.9744
# Epoch 46/50
# 4/4 [==============================] - 19s 4s/step - loss: 4.6242e-04 - accuracy: 1.0000 - val_loss: 0.0681 - val_accuracy: 0.9744
# Epoch 47/50
# 4/4 [==============================] - 12s 3s/step - loss: 5.0826e-04 - accuracy: 1.0000 - val_loss: 0.0671 - val_accuracy: 0.9744
# Epoch 48/50
# 4/4 [==============================] - 10s 3s/step - loss: 3.9973e-04 - accuracy: 1.0000 - val_loss: 0.0663 - val_accuracy: 0.9744
# Epoch 49/50
# 4/4 [==============================] - 10s 2s/step - loss: 4.3738e-04 - accuracy: 1.0000 - val_loss: 0.0661 - val_accuracy: 0.9744
# Epoch 50/50
# 4/4 [==============================] - 11s 3s/step - loss: 4.2668e-04 - accuracy: 1.0000 - val_loss: 0.0662 - val_accuracy: 0.9744

# %% [markdown]
# ### Explanation of training metrices
#
# - Loss: Measures the difference between raw prediction (float) and class (0, 1)
# - Accuracy: Measures the difference between thresholded prediction (0, 1) and class (0, 1)
#
# Here, we differentiate between train loss/accuracy and val loss/accuracy. Both are calculated very similarly, but only the train loss/accuracy is taken into account when training the model, while the val loss/accuracy is only there for us to observe and is not participating in changing any weights in the model.
#
# Below we plot the accuracy and the loss.

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

# epochs as variable
epochs_range = range(epochs)

plt.figure(figsize=(15, 15))
plt.subplot(2, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(2, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# If you want to review good/bad learning curves with over/underfitting, you can do this here (https://machinelearningmastery.com/learning-curves-for-diagnosing-machine-learning-model-performance/).
#
# Sometimes, it is not perfectly clear, whether under/overfitting is actually really bad for the problem we want to solve. Intuitively, we would think, that the validation loss and the validation accuracy are inversely correlated, but sometimes this is not the case. In a case where images with borderline predictions are getting predicted better and their output class changes (beach image is being predicted from 0.4 to 0.6) the loss decreases, while the accuracy increases. However, in a case where an image with a very bad prediction changes from 0.2 to 0.1 (the prediction is a beach but it is actually a forest), the loss decreases further, while the accuracy actually stays the same.
#
# In a perfect world, the loss will decrease and the accuracy increase. If both increase, we can say that the network will start to overfit and both cases will happen at the same time. This means that features are learned that are good for the training data set and not so great for generalization/the validation data set. This will then lead to case 2. However, at the same time the network is still learning useful patterns leading to case 1.
#
# Long story short, overfitting may be considered bad, but whether we should stop training if the network learns bad patterns even though it is continuing to learn good patterns is difficult to answer.
#
# If you observe, that your loss/accuracy curves look really bad, consider changing your dataset size, epochs or learning rate.
#
# Below, we will also calculate the F1-score, more info is to be found here (https://towardsdatascience.com/metrics-to-evaluate-your-machine-learning-algorithm-f10ba6e38234).

# %%
# Get F1-score
predictions = np.argmax(model.predict(x_val), axis=-1)
predictions = predictions.reshape(1,-1)[0]
print(classification_report(y_val, predictions, target_names = [classes[0] + ' (Class 0)',classes[1] + ' (Class 1)']))
# Out:
#                   precision    recall  f1-score   support
#
#  beach (Class 0)       1.00      0.80      0.89        10
# forest (Class 1)       0.83      1.00      0.91        10
#
#         accuracy                           0.90        20
#        macro avg       0.92      0.90      0.90        20
#     weighted avg       0.92      0.90      0.90        20

# %% [markdown]
# # Inference
#
# Next, the previously trained model makes a prediction based on what it has learned from the data on new, unseen inference data.

# %%
import random
from IPython.display import display, Image
# define path
inf_path = HOME + 'Inf/'

# get list of all inference files available
inference_files = [os.path.join(root, name)
                  for root, dirs, files in os.walk(inf_path)
                  for name in files]

# %%
# select random image
rdm_img = random.choice(inference_files)
image_size = (img_size,img_size)

# predict on random image
img = keras.preprocessing.image.load_img(
    rdm_img, target_size=image_size
    )
img_array = keras.preprocessing.image.img_to_array(img)
img_array = tf.expand_dims(img_array, 0)
predictions = model.predict(img_array)

# get score for prediciton
score = predictions[0]

# print results
print(rdm_img)
print(
    'This image is %.1f percent %s and %.1f percent %s.'
    %(score[0] * 100, classes[0], score[1] * 100, classes[1]))

# show image
Image(filename=rdm_img)
# Out:
# ../Data/Inf/beach/24.es-trenc-beach-mallorca-1.jpg
# This image is 100.0 percent beach and 0.0 percent forest.

# %%
# save model
model_save_path = HOME + 'models/beach_forest_50epoch'
model.save(model_save_path)

'''
# load a model with:
model = keras.models.load_model('path/to/location')
'''
# Out:
# INFO:tensorflow:Assets written to: ../Data/models/beach_forest_50epoch/assets

# %% [markdown]
# # Transfer learning
#
# If we do not have a lot of training data, we might try transfer learning instead. Here, we use an already trained network, freeze certain lower layers (base model) and re-train the upper layers with our data. We might get an increase in performance without having to increase the size of our dataset.
#
# I will be creating the base model based on the MobileNetV2 model (https://arxiv.org/abs/1801.04381). It was pre-trained on the ImageNet dataset with millions of images and thousands of classes.

# %%
# it will give us an error, because we are using a non-default image size.
base_model = tf.keras.applications.MobileNetV2(input_shape = (img_size, img_size, 3), include_top = False, weights = "imagenet")
# Out:
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.

# %%
base_model.trainable = False

# %%
model = tf.keras.Sequential([base_model,
                                 tf.keras.layers.GlobalAveragePooling2D(),
                                 tf.keras.layers.Dropout(0.2),
                                 tf.keras.layers.Dense(2, activation="softmax")                                     
                                ])

# %%
# Set learning rate and epochs
lr_transfer = 0.0001
epochs = 50
model.compile(optimizer=tf.keras.optimizers.Adam(lr=lr_transfer),
               loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# train
history = model.fit(x_train,y_train,epochs = epochs , validation_data = (x_val, y_val))
# Out:
# Epoch 1/50
# 2/2 [==============================] - 9s 4s/step - loss: 0.6315 - accuracy: 0.5972 - val_loss: 0.8545 - val_accuracy: 0.4500
# Epoch 2/50
# 2/2 [==============================] - 5s 3s/step - loss: 0.6310 - accuracy: 0.7069 - val_loss: 0.8241 - val_accuracy: 0.4500
# Epoch 3/50
# 2/2 [==============================] - 5s 3s/step - loss: 0.6770 - accuracy: 0.5993 - val_loss: 0.7955 - val_accuracy: 0.5000
# Epoch 4/50
# 2/2 [==============================] - 5s 3s/step - loss: 0.5629 - accuracy: 0.7382 - val_loss: 0.7691 - val_accuracy: 0.5000
# Epoch 5/50
# 2/2 [==============================] - 4s 3s/step - loss: 0.6172 - accuracy: 0.6090 - val_loss: 0.7429 - val_accuracy: 0.5000
# Epoch 6/50
# 2/2 [==============================] - 5s 3s/step - loss: 0
50
# 2/2 [==============================] - 5s 4s/step - loss: 0.2332 - accuracy: 0.9458 - val_loss: 0.3321 - val_accuracy: 0.9500
# Epoch 34/50
# 2/2 [==============================] - 6s 3s/step - loss: 0.2242 - accuracy: 0.9889 - val_loss: 0.3248 - val_accuracy: 0.9500
# Epoch 35/50
# 2/2 [==============================] - 7s 4s/step - loss: 0.2284 - accuracy: 0.9674 - val_loss: 0.3178 - val_accuracy: 0.9500
# Epoch 36/50
# 2/2 [==============================] - 6s 4s/step - loss: 0.2444 - accuracy: 0.9889 - val_loss: 0.3111 - val_accuracy: 0.9500
# Epoch 37/50
# 2/2 [==============================] - 5s 3s/step - loss: 0.2284 - accuracy: 0.9674 - val_loss: 0.3044 - val_accuracy: 0.9500
# Epoch 38/50
# 2/2 [==============================] - 5s 3s/step - loss: 0.2089 - accuracy: 0.9889 - val_loss: 0.2981 - val_accuracy: 0.9500
# Epoch 39/50
# 2/2 [==============================] - 7s 5s/step - loss: 0.2168 - accuracy: 0.9674 - val_loss: 0.2920 - val_accuracy: 0.9500
# Epoch 40/50
# 2/2 [==============================] - 7s 4s/step - loss: 0.1902 - accuracy: 0.9785 - val_loss: 0.2861 - val_accuracy: 0.9500
# Epoch 41/50
# 2/2 [==============================] - 9s 4s/step - loss: 0.2007 - accuracy: 0.9785 - val_loss: 0.2805 - val_accuracy: 0.9500
# Epoch 42/50
# 2/2 [==============================] - 6s 3s/step - loss: 0.2066 - accuracy: 0.9889 - val_loss: 0.2752 - val_accuracy: 0.9500
# Epoch 43/50
# 2/2 [==============================] - 5s 3s/step - loss: 0.2011 - accuracy: 0.9785 - val_loss: 0.2699 - val_accuracy: 0.9500
# Epoch 44/50
# 2/2 [==============================] - 6s 3s/step - loss: 0.1962 - accuracy: 1.0000 - val_loss: 0.2649 - val_accuracy: 0.9500
# Epoch 45/50
# 2/2 [==============================] - 5s 3s/step - loss: 0.1976 - accuracy: 0.9674 - val_loss: 0.2600 - val_accuracy: 0.9500
# Epoch 46/50
# 2/2 [==============================] - 5s 3s/step - loss: 0.1963 - accuracy: 0.9562 - val_loss: 0.2554 - val_accuracy: 0.9500
# Epoch 47/50
# 2/2 [==============================] - 5s 3s/step - loss: 0.1627 - accuracy: 1.0000 - val_loss: 0.2510 - val_accuracy: 0.9500
# Epoch 48/50
# 2/2 [==============================] - 5s 3s/step - loss: 0.1813 - accuracy: 0.9569 - val_loss: 0.2466 - val_accuracy: 0.9500
# Epoch 49/50
# 2/2 [==============================] - 5s 3s/step - loss: 0.1805 - accuracy: 1.0000 - val_loss: 0.2425 - val_accuracy: 0.9500
# Epoch 50/50
# 2/2 [==============================] - 4s 3s/step - loss: 0.1662 - accuracy: 1.0000 - val_loss: 0.2385 - val_accuracy: 0.9500

# %% [markdown]
# ### Visualization of training and validation curves of transfer learning

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs_range = range(epochs)

plt.figure(figsize=(15, 15))
plt.subplot(2, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(2, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# Here we can see, that the training process shows most likely underfitting. We could now increase the learning rate and/or epochs.

# %% [markdown]
# ## Inference on transfer learning

# %%
# pick random image from the inference folder
rdm_img = random.choice(inference_files)
image_size = (img_size,img_size)

# predict
img = keras.preprocessing.image.load_img(
    rdm_img, target_size=image_size
    )
img_array = keras.preprocessing.image.img_to_array(img)
img_array = tf.expand_dims(img_array, 0)
predictions = model.predict(img_array)

# get score
score = predictions[0]
print(
    'This image is %.1f percent %s and %.1f percent %s.'
    %(score[0] * 100, classes[0], score[1] * 100, classes[1]))
Image(filename=rdm_img)
# Out:
# This image is 45.4 percent beach and 54.6 percent forest.

# %% [markdown]
# In this example, transfer learning did apparently not make our predictions better.

# %%
model_save_path = HOME + 'models/beachforest_50epo_transfer'
model.save(model_save_path)
# Out:
# INFO:tensorflow:Assets written to: ../Data/models/beachforest_50epo_transfer/assets

# %% [markdown]
# ## References
#
# - https://keras.io/examples/vision/image_classification_from_scratch/
# - https://www.analyticsvidhya.com/blog/2020/10/create-image-classification-model-python-keras/
