# %% [markdown]
# # Lab Image Processing Class
# ## Image Classification with Keras/Tensorflow
#
# First, we want to make sure to use the GPU instead of the CPU for training for a massive speed improvement. To do that, select Runtime > Change Runtime Type select GPU as Hardware Accelerator. Then, check if the GPU is recognized by running the cell below.
#
# The code will print a list of all devices. Keras will select the GPU for training if it is available.

# %%
# check for graphics
# printing the devices we have available
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 7458855420175168067
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 11154422528
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 10458182795139585355
# physical_device_desc: "device: 0, name: Tesla K80, pci bus id: 0000:00:04.0, compute capability: 3.7"
# ]

# %%
# Imports

# Library allowing downloads of google images
# Does not work for files 
#from google_images_download import google_images_download

# Miscellaneous operating system libraries
import os
import shutil
import numpy as np
import random

# Libraries for plotting
import matplotlib.pyplot as plt
import seaborn as sns
import cv2
from IPython.display import display, Image

# Deep learning libraries Keras and Tensorflow for training and sklearn for the metrics
import keras
from keras.models import Sequential
from keras.layers import Dense, Conv2D , MaxPool2D , Flatten , Dropout 
from keras.preprocessing.image import ImageDataGenerator
from keras.optimizers import Adam
from sklearn.metrics import classification_report,confusion_matrix
import tensorflow as tf

# %% [markdown]
# ## Download images from Google
#
# Below, we will download images from Google based on the search queries we give. You can also use your own images, if you do, I recommend to have the following data structure:
#
# - Lab_image_processing (the Github repository)
#     - Image_classification.ipynb
#     - ...
# - Data
#     - Train
#         - Class 1
#         - Class 2
#     - Val
#         - Class 1
#         - Class 2
#     - Inf
#         - Class 1
#         - Class 2
# - Models
#
# If you want to download images from google, you can use the function below, it will also create the right folder structure.

# %% [markdown]
# ### Code for using google collab
#
# First we will zip the local data from the personal local computer with
# ```bash
# zip -r zip_file.zip folder_to_zip/
# ```
# and then we will upload the file to our google drive.
# In the next step, we will mount our google drive.

# %%
# this is for using google collab
from google.colab import drive
drive.mount('/content/drive')#, force_remount = True)
HOME = '/content/drive/MyDrive/Stockholm_Max/Data/image_classification/'
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### Using the terminal for transferring the data to Collab
#
# When the data is saved 'locally' at Google Collab, it will be much faster to train etc. First we will create a directory in Google Collab, then we will copy our data zip file to that folder and then unzip it. Lastly, we will select the right HOME folder.

# %%
# first we will make a folder in our Google colab space
# !mkdir own_data
# with the command 'ls' you can check what files/folders are in a folder and 
# check if your zipfile is where you want it to be
# !ls /content/drive/MyDrive/image_class/
# Out:
# forests_beaches_data.zip

# %%
# Then, you can copy over your zip file to your new folder
# !cp -r /content/drive/MyDrive/image_class/forests_beaches_data.zip own_data/
# Alternatively, you can just drag and drop the zip file into the folder from 
# your computer, it will upload automatically

# Then, we unzip the zipfile
# !unzip /content/own_data/forests_beaches_data.zip
# Out:
# Archive:  /content/own_data/forests_beaches_data.zip
#    creating: Data/
#    creating: Data/forest/
#   inflating: Data/.DS_Store
#    creating: Data/models/
#   inflating: Data/models/.DS_Store
#    creating: Data/Inf/
#    creating: Data/Inf/forest/
#   inflating: Data/Inf/forest/40.skog-flygfoto2-skogsindustrierna-16-9.jpg
#   inflating: Data/Inf/forest/34.buchenwald_fr%c3%bchling.jpg
#   inflating: Data/Inf/forest/56.1200px-mixed_deciduous_forest_catalonia.jpg
#   inflating: Data/Inf/forest/71.dark_finland_forest.jpg
#   inflating: Data/Inf/forest/88.share.jpg
#   inflating: Data/Inf/forest/96.thecommonwanderer-10_1920x1080_1920x1080_02ca959d02e75881cebaa7a04b3e49aa.jpg
#   inflating: Data/Val/forest/18.img_1845-scaled.jpg-1920x.jpg
#   inflating: Data/Val/forest/19.tree-trunk.jpg
#   inflating: Data/Val/forest/90.timmer.jpg
#   inflating: Data/Val/forest/7.rs930_135120665-low.jpg
#   inflating: Data/Val/forest/52.kuvia-suomesta-kuvaaja-roine-piirainen-8-1.jpg
#   inflating: Data/Val/forest/86.cropped-cfxforest-hero-img-1600x878-1-1.jpg
#   inflating: Data/Val/forest/14.final-cover-forest.jpg
#    creating: Data/Val/beach/
#   inflating: Data/Val/beach/12.experiences_beach.jpg
#   inflating: Data/Val/beach/67.https%3a%2f%2fspecials-images.forbesimg.com%2fdam%2fimageserve%2f1072753294%2f0x0.jpg%3ffit%3dscale.jpg
#   inflating: Data/Val/beach/62.tulum_beach_1.jpg
#   inflating: Data/Val/beach/6.havsbad.%20bettnesand_0.jpg
#   inflating: Data/Val/beach/83.negril-big-beach.jpg
#   inflating: Data/Val/beach/17.pensacolabeach-2020-gettyimages-162419903.jpg
#   inflating: Data/Val/beach/52.es-trenc-beach-mallorca-1.jpg
#   inflating: Data/Val/beach/35.long-beach-phu-quoc-best-beaches-in-vietnam_36e9b14cff.jpeg
#   inflating: Data/Val/beach/90.tylosandfrosakullringenas-pernilsson-toppbild1920x1080.jpg
#   inflating: Data/Val/beach/74.family-on-the-beach.jpg
#   inflating: Data/Val/beach/88.bali88.jpg
#   inflating: Data/Val/beach/4.grass-in-beach-sand.jpg
#   inflating: Data/Val/beach/23.conny_fridh-stenshuvud_-1815-resize-56a4091a3df78cf77280788e.jpg
#   inflating: Data/Val/beach/20.5bfec49248eb12058423acf7.jpg
#   inflating: Data/Val/beach/2.beach-quotes-1559667853.jpg
#   inflating: Data/Val/beach/89.beach-stock.a6ea40bc.jpeg
#   inflating: Data/Val/beach/72.home-large.jpg
#   inflating: Data/Val/beach/25.sunset-beach_background.jpg
#   inflating: Data/Val/beach/34.greece-beaches-1280.jpg
#   inflating: Data/Val/beach/33.sweden--gotland--faro--woman-standing-on-beach-646195987-5930723d5f9b589eb46ca506.jpg

# %%
# To continue, we have to define our home folder
HOME = '/content/Data/'

# %%
# Function to download Google images
# Again, you are welcome to use your own data

def download_images(home_folder, dict_data, classes):
    
    # get response from google
    response = google_images_download.googleimagesdownload()

    # get number of total images to download
    n_images = sum([dict_data[label] for label in dict_data])
    for label in classes:
        
        # creating dictionary of arguments for downloading from google
        # all possible arguments you can find here: 
        # https://google-images-download.readthedocs.io/en/latest/arguments.html
        arguments = {
                    "keywords":label,"limit":n_images,"print_urls":False,
                    "size":"large",
                    "output_directory":home_folder
                    }   
        # passing the arguments to the function
        paths = response.download(arguments)   
        
        # create folder structure
        for one_part in dict_data:
            img_per_set = dict_data[one_part]
            output_folder = home_folder + one_part + '/' + label
            
            if not os.path.exists(output_folder):
                os.makedirs(output_folder)
                
            all_files = os.listdir(home_folder + label)
            
            # go through all downloaded files and split up the data
            # for example: total images 100
            # train:70, val:20, inf: 10
            for index, file in enumerate(all_files):
                if index < img_per_set:
                    
                    # change file name if it ends with the file extension .webp
                    if file.endswith('webp'):
                        file2 = file[:-5]
                        
                        # move files to the designated folders
                        shutil.move(
                            home_folder + label + '/' + file,
                            output_folder + '/' + file2
                                    )
                    else:
                        # move files to the designated folders
                        shutil.move(
                        home_folder + label + '/' + file,
                        output_folder + '/' + file
                                    )
                # update the list of files
                all_files = os.listdir(home_folder + label)

# %%
# define the classes
classes = ['beach', 'forest']

# uncomment if not using google collab and select the right HOME folder
'''
# define our home folder
HOME = '../Data/'
# create dictionary based on how many images we wany per set
dict_folders = {'Train':30, 'Val':10, 'Inf':5}
# pass the arguments and download the images
download_images(HOME, dict_folders, classes)
'''
# Out:
# "\n# define our home folder\nHOME = '../Data/'\n# create dictionary based on how many images we wany per set\ndict_folders = {'Train':30, 'Val':10, 'Inf':5}\n# pass the arguments and download the images\ndownload_images(HOME, dict_folders, classes)\n"

# %% [markdown]
# ## Data preparation

# %%
# function to prepare the data and save the data in memory as numpy arrays
# Important: here we are also going to resize the data, as for most networks,
# all data points have to be the same shape.

def get_data(data_dir, classes, img_size):
    data = [] 
    for label in classes: 
        path = os.path.join(data_dir, label)
        class_num = classes.index(label)
        for img in os.listdir(path):
            try:
                img_arr = cv2.imread(os.path.join(path, img))[...,::-1] #convert BGR to RGB format
                resized_arr = cv2.resize(img_arr, (img_size, img_size)) # Reshaping images to preferred size
                data.append([resized_arr, class_num])
            except Exception as e:
                print(e)
    return np.array(data, dtype=object)

# %%
# Define the target image size, the larger, the more features, but also longer training times.
# If you have a decent laptop, 256 pixels is fine.
img_size = 512

train = get_data(HOME + 'Train/', classes, img_size)
val = get_data(HOME + 'Val/', classes, img_size)
# Out:
# 'NoneType' object is not subscriptable

# %%
# view the data and review how many of the training images are availabe
# useful to verify that we loaded all the images from the training data set as numpy arrays
# sometimes, with faulty file endings, there might be errors
l = []
for i in train:
    if(i[1] == 0):
        l.append(classes[0])
    else:
        l.append(classes[1])
sns.set_style('darkgrid')
sns.countplot(x=l)

# %%
# show one image from the first class
plt.figure(figsize = (5,5))
plt.imshow(train[1][0])
plt.title(classes[train[0][1]])
# Out:
# Text(0.5, 1.0, 'beach')

# %%
# show one image from the second class
plt.figure(figsize = (5,5))
plt.imshow(train[-1][0])
plt.title(classes[train[-1][1]])
# Out:
# Text(0.5, 1.0, 'forest')

# %%
# Data preprocessing

x_train = []
y_train = []
x_val = []
y_val = []

for feature, label in train:
    x_train.append(feature)
    y_train.append(label)

for feature, label in val:
    x_val.append(feature)
    y_val.append(label)

# Normalize the data
x_train = np.array(x_train) / 255
x_val = np.array(x_val) / 255

x_train.reshape(-1, img_size, img_size, 1)
y_train = np.array(y_train)

x_val.reshape(-1, img_size, img_size, 1)
y_val = np.array(y_val)

# %%
# data augmentation on training data
datagen = ImageDataGenerator(
        featurewise_center=False,  # set input mean to 0 over the dataset
        samplewise_center=False,  # set each sample mean to 0
        featurewise_std_normalization=False,  # divide inputs by std of the dataset
        samplewise_std_normalization=False,  # divide each input by its std
        zca_whitening=False,  # apply ZCA whitening
        rotation_range = 30,  # randomly rotate images in the range (degrees, 0 to 180)
        zoom_range = 0.2, # Randomly zoom image 
        width_shift_range=0.1,  # randomly shift images horizontally (fraction of total width)
        height_shift_range=0.1,  # randomly shift images vertically (fraction of total height)
        horizontal_flip = True,  # randomly flip images
        vertical_flip=False)  # randomly flip images


datagen.fit(x_train)

# %% [markdown]
# ## Model Definition

# %%
# Define the model 
# This is a simple CNN model with 3 Convolutional layers that are then followed by max-pooling layer.
# Finally, a dropout layer is added to avoid overfitting (it might still happen).

model = Sequential()
model.add(Conv2D(32,3,padding="same", activation="relu", input_shape=(img_size,img_size,3)))
model.add(MaxPool2D())

model.add(Conv2D(32, 3, padding="same", activation="relu"))
model.add(MaxPool2D())

model.add(Conv2D(64, 3, padding="same", activation="relu"))
model.add(MaxPool2D())
model.add(Dropout(0.4))

model.add(Flatten())
model.add(Dense(128,activation="relu"))
model.add(Dense(2, activation="softmax"))

model.summary()

# A summary of the model is going to be printed below
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_6 (Conv2D)            (None, 512, 512, 32)      896
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 256, 256, 32)      0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 256, 256, 32)      9248
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 128, 128, 32)      0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 128, 128, 64)      18496
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 64, 64, 64)        0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 64, 64, 64)        0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 262144)            0
# _________________________________________________________________
# dense_4 (Dense)              (None, 128)               33554560
# _________________________________________________________________
# dense_5 (Dense)              (None, 2)                 258
# =================================================================
# Total params: 33,583,458
# Trainable params: 33,583,458
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Training

# %% [markdown]
# Now we define what kind of optimizer we use for the training process. There are many different optimizers that you could choose from and you can find them here (https://keras.io/api/optimizers/). For now, I will choose the Adam optimizer. It is a stochastic gradient descent method based on adaptive estimation of first-order and second-order moments (From https://keras.io/api/optimizers/adam/).
#
# We will also have to set the learning rate (float from 0.0 - 1.0) for our stochastic gradient descent. The learning rate can be defined as the amount that the weights are updated during training per epoch. It controls how quickly the model tries to adapt to the problem. With larger learning rates the model might learn too quickly and unstable, while with smaller learning rates the model needs more epochs to finish training successfully (more info here https://machinelearningmastery.com/understand-the-dynamics-of-learning-rate-on-deep-learning-neural-networks/).
#
# Apart from the size of the data set, the learning rate and the number of epochs might be the two most important parameters for using deep learning algorithms.

# %%
# Set learning rate and epochs
lr_training = 0.00001
epochs = 200

# Set the optimizer and compile model
opt = Adam(lr_training)


# set the loss calculation, here it is Sparse Categorical Crossentropy 
# (https://www.tensorflow.org/api_docs/python/tf/keras/losses/SparseCategoricalCrossentropy)
model.compile(
    optimizer = opt , loss = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True), 
    metrics = ['accuracy']
            )

# %%
# start the training
# this step might take a while depending on the size of the data set, the number of epochs and your computational power.
history = model.fit(x_train,y_train,epochs = epochs , validation_data = (x_val, y_val))
# Out:
# Epoch 1/200
# 5/5 [==============================] - 2s 367ms/step - loss: 0.6587 - accuracy: 0.5995 - val_loss: 0.5462 - val_accuracy: 0.6500
# Epoch 2/200
# 5/5 [==============================] - 2s 310ms/step - loss: 0.5002 - accuracy: 0.7671 - val_loss: 0.4356 - val_accuracy: 0.8500
# Epoch 3/200
# 5/5 [==============================] - 2s 311ms/step - loss: 0.4062 - accuracy: 0.8858 - val_loss: 0.3909 - val_accuracy: 0.8250
# Epoch 4/200
# 5/5 [==============================] - 2s 313ms/step - loss: 0.3322 - accuracy: 0.8883 - val_loss: 0.3556 - val_accuracy: 0.8500
# Epoch 5/200
# 5/5 [==============================] - 2s 313ms/step - loss: 0.3257 - accuracy: 0.8658 - val_loss: 0.3605 - val_accuracy: 0.8250
# Epoch 6/200
# 5/5 [==============================] - 2s 318ms/step - loss: 0.2992 - accuracy: 0.9160 - val_loss: 0.2606 - val_accuracy: 0.9500
# Epoch 7/200
# 5/5 [==============================] - 2s 313ms/step - loss: 0.2791 - accuracy: 0.9498 - val_loss: 0.3318 - val_accuracy: 0.8250
# Epoch 8/200
# 5/5 [==============================] - 2s 317ms/step - loss: 0.2566 - accuracy: 0.8879 - val_loss: 0.3505 - val_accuracy: 0.8250
# Epoch 9/200
# 5/5 [==============================] - 2s 317ms/step - loss: 0.2170 - accuracy: 0.9281 - val_loss: 0.2233 - val_accuracy: 0.9250
# Epoch 10/200
# 5/5 [==============================] - 2s 319ms/step - loss: 0.2127 - accuracy: 0.9576 - val_loss: 0.2268 - val_accuracy: 0.9250
# Epoch 11/200
# 5/5 [==============================] - 2s 310ms/step - loss: 0.1833 - accuracy: 0.9537 - val_loss: 0.2265 - val_accuracy: 0.9250
# Epoch 12/200
# 5/5 [==============================] - 2s 313ms/step - loss: 0.1643 - accuracy: 0.9494 - val_loss: 0.2411 - val_accuracy: 0.9250
# Epoch 13/200
# 5/5 [==============================] - 2s 315ms/step - loss: 0.1630 - accuracy: 0.9606 - val_loss: 0.2230 - val_accuracy: 0.9250
# Epoch 14/200
# 5/5 [==============================] - 2s 310ms/step - loss: 0
200
# 5/5 [==============================] - 2s 311ms/step - loss: 0.0194 - accuracy: 1.0000 - val_loss: 0.2006 - val_accuracy: 0.9500
# Epoch 80/200
# 5/5 [==============================] - 2s 319ms/step - loss: 0.0168 - accuracy: 1.0000 - val_loss: 0.2055 - val_accuracy: 0.9500
# Epoch 81/200
# 5/5 [==============================] - 2s 314ms/step - loss: 0.0195 - accuracy: 1.0000 - val_loss: 0.2100 - val_accuracy: 0.9500
# Epoch 82/200
# 5/5 [==============================] - 2s 314ms/step - loss: 0.0186 - accuracy: 1.0000 - val_loss: 0.1957 - val_accuracy: 0.9500
# Epoch 83/200
# 5/5 [==============================] - 2s 310ms/step - loss: 0.0177 - accuracy: 1.0000 - val_loss: 0.1906 - val_accuracy: 0.9500
# Epoch 84/200
# 5/5 [==============================] - 2s 312ms/step - loss: 0.0160 - accuracy: 1.0000 - val_loss: 0.1772 - val_accuracy: 0.9500
# Epoch 85/200
# 5/5 [==============================] - 2s 316ms/step - loss: 0.0181 - accuracy: 1.0000 - val_loss: 0.1786 - val_accuracy: 0.9500
# Epoch 86/200
# 5/5 [==============================] - 2s 315ms/step - loss: 0.0197 - accuracy: 1.0000 - val_loss: 0.1934 - val_accuracy: 0.9500
# Epoch 87/200
# 5/5 [==============================] - 2s 316ms/step - loss: 0.0165 - accuracy: 1.0000 - val_loss: 0.1983 - val_accuracy: 0.9500
# Epoch 88/200
# 5/5 [==============================] - 2s 314ms/step - loss: 0.0168 - accuracy: 1.0000 - val_loss: 0.1764 - val_accuracy: 0.9500
# Epoch 89/200
# 5/5 [==============================] - 2s 315ms/step - loss: 0.0164 - accuracy: 1.0000 - val_loss: 0.1795 - val_accuracy: 0.9500
# Epoch 90/200
# 5/5 [==============================] - 2s 315ms/step - loss: 0.0129 - accuracy: 1.0000 - val_loss: 0.2212 - val_accuracy: 0.9500
# Epoch 91/200
# 5/5 [==============================] - 2s 316ms/step - loss: 0.0152 - accuracy: 1.0000 - val_loss: 0.2745 - val_accuracy: 0.9250
# Epoch 92/200
# 5/5 [==============================] - 2s 315ms/step - loss: 0.0154 - accuracy: 1.0000 - val_loss: 0.2466 - val_accuracy: 0.9500
# Epoch 93/200
# 5/5 [==============================] - 2s 314ms/step - loss: 0.0153 - accuracy: 1.0000 - val_loss: 0.2088 - val_accuracy: 0.9500
# Epoch 94/200
# 5/5 [==============================] - 2s 309ms/step - loss: 0.0103 - accuracy: 1.0000 - val_loss: 0.1799 - val_accuracy: 0.9500
# Epoch 95/200
# 5/5 [==============================] - 2s 317ms/step - loss: 0.0139 - accuracy: 1.0000 - val_loss: 0.1737 - val_accuracy: 0.9500
# Epoch 96/200
# 5/5 [==============================] - 2s 317ms/step - loss: 0.0146 - accuracy: 1.0000 - val_loss: 0.1844 - val_accuracy: 0.9500
# Epoch 97/200
# 5/5 [==============================] - 2s 316ms/step - loss: 0.0119 - accuracy: 1.0000 - val_loss: 0.2015 - val_accuracy: 0.9500
# Epoch 98/200
# 5/5 [==============================] - 2s 316ms/step - loss: 0.0127 - accuracy: 1.0000 - val_loss: 0.2169 - val_accuracy: 0.9500
# Epoch 99/200
# 5/5 [==============================] - 2s 314ms/step - loss: 0.0107 - accuracy: 1.0000 - val_loss: 0.2164 - val_accuracy: 0.9500
# Epoch 100/200
# 5/5 [==============================] - 2s 316ms/step - loss: 0.0124 - accuracy: 1.0000 - val_loss: 0.2219 - val_accuracy: 0.9500
# Epoch 101/200
# 5/5 [==============================] - 2s 316ms/step - loss: 0.0106 - accuracy: 1.0000 - val_loss: 0.2281 - val_accuracy: 0.9500
# Epoch 102/200
# 5/5 [==============================] - 2s 311ms/step - loss: 0.0114 - accuracy: 1.0000 - val_loss: 0.2191 - val_accuracy: 0.9500
# Epoch 103/200
# 5/5 [==============================] - 2s 315ms/step - loss: 0.0106 - accuracy: 1.0000 - val_loss: 0.2142 - val_accuracy: 0.9500
# Epoch 104/200
# 5/5 [==============================] - 2s 316ms/step - loss: 0.0112 - accuracy: 1.0000 - val_loss: 0.2054 - val_accuracy: 0.9500
# Epoch 105/200
# 5/5 [==============================] - 2s 310ms/step - loss: 0.0092 - accuracy: 1.0000 - val_loss: 0.2101 - val_accuracy: 0.9500
# Epoch 106/200
# 5/5 [==============================] - 2s 312ms/step - loss: 0.0112 - accuracy: 1.0000 - val_loss: 0.2088 - val_accuracy: 0.9500
# Epoch 107/200
# 5/5 [==============================] - 2s 314ms/step - loss: 0.0111 - accuracy: 1.0000 - val_loss: 0.2098 - val_accuracy: 0.9500
# Epoch 108/200
# 5/5 [==============================] - 2s 307ms/step - loss: 0.0092 - accuracy: 1.0000 - val_loss: 0.2104 - val_accuracy: 0.9500
# Epoch 109/200
# 5/5 [==============================] - 2s 315ms/step - loss: 0.0113 - accuracy: 1.0000 - val_loss: 0.2045 - val_accuracy: 0.9500
# Epoch 110/200
# 5/5 [==============================] - 2s 313ms/step - loss: 0.0089 - accuracy: 1.0000 - val_loss: 0.2033 - val_accuracy: 0.9500
# Epoch 111/200
# 5/5 [==============================] - 2s 316ms/step - loss: 0.0090 - accuracy: 1.0000 - val_loss: 0.2059 - val_accuracy: 0.9500
# Epoch 112/200
# 5/5 [==============================] - 2s 319ms/step - loss: 0.0088 - accuracy: 1.0000 - val_loss: 0.2084 - val_accuracy: 0.9500
# Epoch 113/200
# 5/5 [==============================] - 2s 314ms/step - loss: 0.0089 - accuracy: 1.0000 - val_loss: 0.2114 - val_accuracy: 0.9500
# Epoch 114/200
# 5/5 [==============================] - 2s 315ms/step - loss: 0.0093 - accuracy: 1.0000 - val_loss: 0.2152 - val_accuracy: 0.9500
# Epoch 115/200
# 5/5 [==============================] - 2s 317ms/step - loss: 0.0098 - accuracy: 1.0000 - val_loss: 0.2149 - val_accuracy: 0.9500
# Epoch 116/200
# 5/5 [==============================] - 2s 317ms/step - loss: 0.0089 - accuracy: 1.0000 - val_loss: 0.2178 - val_accuracy: 0.9500
# Epoch 117/200
# 5/5 [==============================] - 2s 318ms/step - loss: 0.0084 - accuracy: 1.0000 - val_loss: 0.2196 - val_accuracy: 0.9500
# Epoch 118/200
# 5/5 [==============================] - 2s 317ms/step - loss: 0.0061 - accuracy: 1.0000 - val_loss: 0.1901 - val_accuracy: 0.9500
# Epoch 119/200
# 5/5 [==============================] - 2s 310ms/step - loss: 0.0079 - accuracy: 1.0000 - val_loss: 0.1763 - val_accuracy: 0.9500
# Epoch 120/200
# 5/5 [==============================] - 2s 317ms/step - loss: 0.0078 - accuracy: 1.0000 - val_loss: 0.1866 - val_accuracy: 0.9500
# Epoch 121/200
# 5/5 [==============================] - 2s 318ms/step - loss: 0.0081 - accuracy: 1.0000 - val_loss: 0.2071 - val_accuracy: 0.9500
# Epoch 122/200
# 5/5 [==============================] - 2s 309ms/step - loss: 0.0073 - accuracy: 1.0000 - val_loss: 0.2189 - val_accuracy: 0.9500
# Epoch 123/200
# 5/5 [==============================] - 2s 314ms/step - loss: 0.0071 - accuracy: 1.0000 - val_loss: 0.2221 - val_accuracy: 0.9500
# Epoch 124/200
# 5/5 [==============================] - 2s 317ms/step - loss: 0.0070 - accuracy: 1.0000 - val_loss: 0.2104 - val_accuracy: 0.9500
# Epoch 125/200
# 5/5 [==============================] - 2s 320ms/step - loss: 0.0077 - accuracy: 1.0000 - val_loss: 0.2010 - val_accuracy: 0.9500
# Epoch 126/200
# 5/5 [==============================] - 2s 313ms/step - loss: 0.0076 - accuracy: 1.0000 - val_loss: 0.2022 - val_accuracy: 0.9500
# Epoch 127/200
# 5/5 [==============================] - 2s 318ms/step - loss: 0.0069 - accuracy: 1.0000 - val_loss: 0.1917 - val_accuracy: 0.9500
# Epoch 128/200
# 5/5 [==============================] - 2s 324ms/step - loss: 0.0062 - accuracy: 1.0000 - val_loss: 0.1933 - val_accuracy: 0.9500
# Epoch 129/200
# 5/5 [==============================] - 2s 323ms/step - loss: 0.0075 - accuracy: 1.0000 - val_loss: 0.2028 - val_accuracy: 0.9500
# Epoch 130/200
# 5/5 [==============================] - 2s 311ms/step - loss: 0.0052 - accuracy: 1.0000 - val_loss: 0.2098 - val_accuracy: 0.9500
# Epoch 131/200
# 5/5 [==============================] - 2s 316ms/step - loss: 0.0061 - accuracy: 1.0000 - val_loss: 0.2156 - val_accuracy: 0.9500
# Epoch 132/200
# 5/5 [==============================] - 2s 317ms/step - loss: 0.0054 - accuracy: 1.0000 - val_loss: 0.2182 - val_accuracy: 0.9500
# Epoch 133/200
# 5/5 [==============================] - 2s 311ms/step - loss: 0.0054 - accuracy: 1.0000 - val_loss: 0.2197 - val_accuracy: 0.9500
# Epoch 134/200
# 5/5 [==============================] - 2s 314ms/step - loss: 0.0059 - accuracy: 1.0000 - val_loss: 0.2129 - val_accuracy: 0.9500
# Epoch 135/200
# 5/5 [==============================] - 2s 316ms/step - loss: 0.0060 - accuracy: 1.0000 - val_loss: 0.1993 - val_accuracy: 0.9500
# Epoch 136/200
# 5/5 [==============================] - 2s 323ms/step - loss: 0.0067 - accuracy: 1.0000 - val_loss: 0.1679 - val_accuracy: 0.9500
# Epoch 137/200
# 5/5 [==============================] - 2s 312ms/step - loss: 0.0078 - accuracy: 1.0000 - val_loss: 0.1691 - val_accuracy: 0.9500
# Epoch 138/200
# 5/5 [==============================] - 2s 314ms/step - loss: 0.0058 - accuracy: 1.0000 - val_loss: 0.1668 - val_accuracy: 0.9500
# Epoch 139/200
# 5/5 [==============================] - 2s 310ms/step - loss: 0.0061 - accuracy: 1.0000 - val_loss: 0.1657 - val_accuracy: 0.9500
# Epoch 140/200
# 5/5 [==============================] - 2s 320ms/step - loss: 0.0056 - accuracy: 1.0000 - val_loss: 0.2188 - val_accuracy: 0.9500
# Epoch 141/200
# 5/5 [==============================] - 2s 318ms/step - loss: 0.0050 - accuracy: 1.0000 - val_loss: 0.2547 - val_accuracy: 0.9500
# Epoch 142/200
# 5/5 [==============================] - 2s 307ms/step - loss: 0.0063 - accuracy: 1.0000 - val_loss: 0.2426 - val_accuracy: 0.9500
# Epoch 143/200
# 5/5 [==============================] - 2s 319ms/step - loss: 0.0064 - accuracy: 1.0000 - val_loss: 0.1939 - val_accuracy: 0.9500
# Epoch 144/200
# 5/5 [==============================] - 2s 315ms/step - loss: 0.0058 - accuracy: 1.0000 - val_loss: 0.1774 - val_accuracy: 0.9500
# Epoch 145/200
# 5/5 [==============================] - 2s 312ms/step - loss: 0.0053 - accuracy: 1.0000 - val_loss: 0.1841 - val_accuracy: 0.9500
# Epoch 146/200
# 5/5 [==============================] - 2s 316ms/step - loss: 0.0053 - accuracy: 1.0000 - val_loss: 0.2060 - val_accuracy: 0.9500
# Epoch 147/200
# 5/5 [==============================] - 2s 316ms/step - loss: 0.0052 - accuracy: 1.0000 - val_loss: 0.2094 - val_accuracy: 0.9500
# Epoch 148/200
# 5/5 [==============================] - 2s 311ms/step - loss: 0.0042 - accuracy: 1.0000 - val_loss: 0.1834 - val_accuracy: 0.9500
# Epoch 149/200
# 5/5 [==============================] - 2s 306ms/step - loss: 0.0046 - accuracy: 1.0000 - val_loss: 0.1791 - val_accuracy: 0.9500
# Epoch 150/200
# 5/5 [==============================] - 2s 317ms/step - loss: 0.0049 - accuracy: 1.0000 - val_loss: 0.1881 - val_accuracy: 0.9500
# Epoch 151/200
# 5/5 [==============================] - 2s 316ms/step - loss: 0.0056 - accuracy: 1.0000 - val_loss: 0.2021 - val_accuracy: 0.9500
# Epoch 152/200
# 5/5 [==============================] - 2s 315ms/step - loss: 0.0040 - accuracy: 1.0000 - val_loss: 0.2145 - val_accuracy: 0.9500
# Epoch 153/200
# 5/5 [==============================] - 2s 309ms/step - loss: 0.0044 - accuracy: 1.0000 - val_loss: 0.2263 - val_accuracy: 0.9500
# Epoch 154/200
# 5/5 [==============================] - 2s 320ms/step - loss: 0.0047 - accuracy: 1.0000 - val_loss: 0.2319 - val_accuracy: 0.9500
# Epoch 155/200
# 5/5 [==============================] - 2s 309ms/step - loss: 0.0040 - accuracy: 1.0000 - val_loss: 0.2167 - val_accuracy: 0.9500
# Epoch 156/200
# 5/5 [==============================] - 2s 325ms/step - loss: 0.0041 - accuracy: 1.0000 - val_loss: 0.1716 - val_accuracy: 0.9500
# Epoch 157/200
# 5/5 [==============================] - 2s 324ms/step - loss: 0.0051 - accuracy: 1.0000 - val_loss: 0.1571 - val_accuracy: 0.9500
# Epoch 158/200
# 5/5 [==============================] - 2s 316ms/step - loss: 0.0036 - accuracy: 1.0000 - val_loss: 0.1501 - val_accuracy: 0.9500
# Epoch 159/200
# 5/5 [==============================] - 2s 315ms/step - loss: 0.0050 - accuracy: 1.0000 - val_loss: 0.1688 - val_accuracy: 0.9500
# Epoch 160/200
# 5/5 [==============================] - 2s 316ms/step - loss: 0.0038 - accuracy: 1.0000 - val_loss: 0.1960 - val_accuracy: 0.9500
# Epoch 161/200
# 5/5 [==============================] - 2s 309ms/step - loss: 0.0038 - accuracy: 1.0000 - val_loss: 0.2203 - val_accuracy: 0.9500
# Epoch 162/200
# 5/5 [==============================] - 2s 315ms/step - loss: 0.0039 - accuracy: 1.0000 - val_loss: 0.2299 - val_accuracy: 0.9500
# Epoch 163/200
# 5/5 [==============================] - 2s 317ms/step - loss: 0.0036 - accuracy: 1.0000 - val_loss: 0.2315 - val_accuracy: 0.9500
# Epoch 164/200
# 5/5 [==============================] - 2s 311ms/step - loss: 0.0040 - accuracy: 1.0000 - val_loss: 0.2236 - val_accuracy: 0.9500
# Epoch 165/200
# 5/5 [==============================] - 2s 306ms/step - loss: 0.0035 - accuracy: 1.0000 - val_loss: 0.2079 - val_accuracy: 0.9500
# Epoch 166/200
# 5/5 [==============================] - 2s 315ms/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 0.2021 - val_accuracy: 0.9500
# Epoch 167/200
# 5/5 [==============================] - 2s 308ms/step - loss: 0.0032 - accuracy: 1.0000 - val_loss: 0.2024 - val_accuracy: 0.9500
# Epoch 168/200
# 5/5 [==============================] - 2s 311ms/step - loss: 0.0039 - accuracy: 1.0000 - val_loss: 0.2076 - val_accuracy: 0.9500
# Epoch 169/200
# 5/5 [==============================] - 2s 310ms/step - loss: 0.0032 - accuracy: 1.0000 - val_loss: 0.2129 - val_accuracy: 0.9500
# Epoch 170/200
# 5/5 [==============================] - 2s 312ms/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 0.2158 - val_accuracy: 0.9500
# Epoch 171/200
# 5/5 [==============================] - 2s 313ms/step - loss: 0.0032 - accuracy: 1.0000 - val_loss: 0.2165 - val_accuracy: 0.9500
# Epoch 172/200
# 5/5 [==============================] - 2s 316ms/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 0.2217 - val_accuracy: 0.9500
# Epoch 173/200
# 5/5 [==============================] - 2s 328ms/step - loss: 0.0031 - accuracy: 1.0000 - val_loss: 0.2270 - val_accuracy: 0.9500
# Epoch 174/200
# 5/5 [==============================] - 2s 311ms/step - loss: 0.0031 - accuracy: 1.0000 - val_loss: 0.2265 - val_accuracy: 0.9500
# Epoch 175/200
# 5/5 [==============================] - 2s 313ms/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 0.2232 - val_accuracy: 0.9500
# Epoch 176/200
# 5/5 [==============================] - 2s 311ms/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 0.2177 - val_accuracy: 0.9500
# Epoch 177/200
# 5/5 [==============================] - 2s 316ms/step - loss: 0.0033 - accuracy: 1.0000 - val_loss: 0.2115 - val_accuracy: 0.9500
# Epoch 178/200
# 5/5 [==============================] - 2s 312ms/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 0.2116 - val_accuracy: 0.9500
# Epoch 179/200
# 5/5 [==============================] - 2s 318ms/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.2162 - val_accuracy: 0.9500
# Epoch 180/200
# 5/5 [==============================] - 2s 319ms/step - loss: 0.0033 - accuracy: 1.0000 - val_loss: 0.2194 - val_accuracy: 0.9500
# Epoch 181/200
# 5/5 [==============================] - 2s 311ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.2178 - val_accuracy: 0.9500
# Epoch 182/200
# 5/5 [==============================] - 2s 310ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.2148 - val_accuracy: 0.9500
# Epoch 183/200
# 5/5 [==============================] - 2s 314ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.2148 - val_accuracy: 0.9500
# Epoch 184/200
# 5/5 [==============================] - 2s 316ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.2177 - val_accuracy: 0.9500
# Epoch 185/200
# 5/5 [==============================] - 2s 311ms/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 0.2259 - val_accuracy: 0.9500
# Epoch 186/200
# 5/5 [==============================] - 2s 318ms/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 0.2314 - val_accuracy: 0.9500
# Epoch 187/200
# 5/5 [==============================] - 2s 306ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.2283 - val_accuracy: 0.9500
# Epoch 188/200
# 5/5 [==============================] - 2s 308ms/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.2232 - val_accuracy: 0.9500
# Epoch 189/200
# 5/5 [==============================] - 2s 318ms/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 0.2190 - val_accuracy: 0.9500
# Epoch 190/200
# 5/5 [==============================] - 2s 311ms/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 0.2154 - val_accuracy: 0.9500
# Epoch 191/200
# 5/5 [==============================] - 2s 315ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.2157 - val_accuracy: 0.9500
# Epoch 192/200
# 5/5 [==============================] - 2s 315ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.2175 - val_accuracy: 0.9500
# Epoch 193/200
# 5/5 [==============================] - 2s 315ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.2187 - val_accuracy: 0.9500
# Epoch 194/200
# 5/5 [==============================] - 2s 319ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.2174 - val_accuracy: 0.9500
# Epoch 195/200
# 5/5 [==============================] - 2s 319ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.2080 - val_accuracy: 0.9500
# Epoch 196/200
# 5/5 [==============================] - 2s 314ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.2019 - val_accuracy: 0.9500
# Epoch 197/200
# 5/5 [==============================] - 2s 313ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.2104 - val_accuracy: 0.9500
# Epoch 198/200
# 5/5 [==============================] - 2s 311ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.2345 - val_accuracy: 0.9500
# Epoch 199/200
# 5/5 [==============================] - 2s 320ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.2455 - val_accuracy: 0.9500
# Epoch 200/200
# 5/5 [==============================] - 2s 314ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.2452 - val_accuracy: 0.9500

# %% [markdown]
# ### Explanation of training metrices
#
# - Loss: Measures the difference between raw prediction (float) and class (0, 1)
# - Accuracy: Measures the difference between thresholded prediction (0, 1) and class (0, 1)
#
# Here, we differentiate between train loss/accuracy and val loss/accuracy. Both are calculated very similarly, but only the train loss/accuracy is taken into account when training the model, while the val loss/accuracy is only there for us to observe and is not participating in changing any weights in the model.
#
# Below we plot the accuracy and the loss.

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

# epochs as variable
epochs_range = range(epochs)

plt.figure(figsize=(15, 15))
plt.subplot(2, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(2, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# If you want to review good/bad learning curves with over/underfitting, you can do this here (https://machinelearningmastery.com/learning-curves-for-diagnosing-machine-learning-model-performance/).
#
# Sometimes, it is not perfectly clear, whether under/overfitting is actually really bad for the problem we want to solve. Intuitively, we would think, that the validation loss and the validation accuracy are inversely correlated, but sometimes this is not the case. In a case where images with borderline predictions are getting predicted better and their output class changes (beach image is being predicted from 0.4 to 0.6) the loss decreases, while the accuracy increases. However, in a case where an image with a very bad prediction changes from 0.2 to 0.1 (the prediction is a beach but it is actually a forest), the loss decreases further, while the accuracy actually stays the same.
#
# In a perfect world, the loss will decrease and the accuracy increase. If both increase, we can say that the network will start to overfit and both cases will happen at the same time. This means that features are learned that are good for the training data set and not so great for generalization/the validation data set. This will then lead to case 2. However, at the same time the network is still learning useful patterns leading to case 1.
#
# Long story short, overfitting may be considered bad, but whether we should stop training if the network learns bad patterns even though it is continuing to learn good patterns is difficult to answer.
#
# If you observe, that your loss/accuracy curves look really bad, consider changing your dataset size, epochs or learning rate.
#
# Below, we will also calculate the F1-score, more info is to be found here (https://towardsdatascience.com/metrics-to-evaluate-your-machine-learning-algorithm-f10ba6e38234).

# %%
# Get F1-score
predictions = np.argmax(model.predict(x_val), axis=-1)
predictions = predictions.reshape(1,-1)[0]
print(classification_report(y_val, predictions, target_names = [classes[0] + ' (Class 0)',classes[1] + ' (Class 1)']))
# Out:
#                   precision    recall  f1-score   support
#
#  beach (Class 0)       0.91      1.00      0.95        20
# forest (Class 1)       1.00      0.90      0.95        20
#
#         accuracy                           0.95        40
#        macro avg       0.95      0.95      0.95        40
#     weighted avg       0.95      0.95      0.95        40

# %% [markdown]
# # Inference
#
# Next, the previously trained model makes a prediction based on what it has learned from the data on new, unseen inference data.

# %%
import random
from IPython.display import display, Image
# define path
inf_path = HOME + 'Inf/'

# get list of all inference files available
inference_files = [os.path.join(root, name)
                  for root, dirs, files in os.walk(inf_path)
                  for name in files]

# %%
# select random image
rdm_img = random.choice(inference_files)
image_size = (img_size,img_size)

# predict on random image
img = keras.preprocessing.image.load_img(
    rdm_img, target_size=image_size
    )
img_array = keras.preprocessing.image.img_to_array(img)
img_array = tf.expand_dims(img_array, 0)
predictions = model.predict(img_array)

# get score for prediciton
score = predictions[0]

# print results
print(rdm_img)
print(
    'This image is %.1f percent %s and %.1f percent %s.'
    %(score[0] * 100, classes[0], score[1] * 100, classes[1]))

# show image
Image(filename=rdm_img)
# Out:
# /content/Data/Inf/beach/9.bondi-beach-sydney.jpg
# This image is 100.0 percent beach and 0.0 percent forest.

# %%
# Here you can save the model and download it to use it on your personal
# computer. The prediction/inference tasks are usually not very computing-
# heavy and can easily be done on your own computer.
model_save_path = HOME + 'models/beach_forest_50epoch'
model.save(model_save_path)


# With the line below you can load your model in another script to do prediction
#model = keras.models.load_model('path/to/location')
# Out:
# INFO:tensorflow:Assets written to: /content/Data/models/beach_forest_50epoch/assets

# %% [markdown]
# # Transfer learning
#
# If we do not have a lot of training data, we might try transfer learning instead. Here, we use an already trained network, freeze certain lower layers (base model) and re-train the upper layers with our data. We might get an increase in performance without having to increase the size of our dataset.
#
# I will be creating the base model based on the MobileNetV2 model (https://arxiv.org/abs/1801.04381). It was pre-trained on the ImageNet dataset with millions of images and thousands of classes.

# %%
# it will give us an error, because we are using a non-default image size.
base_model = tf.keras.applications.MobileNetV2(input_shape = (img_size, img_size, 3), include_top = False, weights = "imagenet")
# Out:
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_224_no_top.h5
# 9412608/9406464 [==============================] - 0s 0us/step

# %%
base_model.trainable = False

# %%
model = tf.keras.Sequential([base_model,
                                 tf.keras.layers.GlobalAveragePooling2D(),
                                 tf.keras.layers.Dropout(0.2),
                                 tf.keras.layers.Dense(2, activation="softmax")                                     
                                ])

# %%
# Set learning rate and epochs
lr_transfer = 0.0001
epochs = 200
model.compile(optimizer=tf.keras.optimizers.Adam(lr=lr_transfer),
               loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# train
history = model.fit(x_train,y_train,epochs = epochs , validation_data = (x_val, y_val))
# Out:
# Epoch 1/200
# 5/5 [==============================] - 6s 684ms/step - loss: 0.3403 - accuracy: 0.8844 - val_loss: 0.3584 - val_accuracy: 0.9250
# Epoch 2/200
# 5/5 [==============================] - 2s 462ms/step - loss: 0.3372 - accuracy: 0.9125 - val_loss: 0.3460 - val_accuracy: 0.9250
# Epoch 3/200
# 5/5 [==============================] - 2s 459ms/step - loss: 0.3045 - accuracy: 0.9684 - val_loss: 0.3339 - val_accuracy: 0.9250
# Epoch 4/200
# 5/5 [==============================] - 2s 454ms/step - loss: 0.3145 - accuracy: 0.9281 - val_loss: 0.3233 - val_accuracy: 0.9250
# Epoch 5/200
# 5/5 [==============================] - 2s 460ms/step - loss: 0.3077 - accuracy: 0.9207 - val_loss: 0.3154 - val_accuracy: 0.9250
# Epoch 6/200
# 5/5 [==============================] - 2s 459ms/step - loss: 0.2745 - accuracy: 0.9502 - val_loss: 0.3069 - val_accuracy: 0.9250
# Epoch 7/200
# 5/5 [==============================] - 2s 455ms/step - loss: 0
200
# 5/5 [==============================] - 2s 454ms/step - loss: 0.1063 - accuracy: 0.9862 - val_loss: 0.1306 - val_accuracy: 0.9750
# Epoch 68/200
# 5/5 [==============================] - 2s 458ms/step - loss: 0.1090 - accuracy: 0.9961 - val_loss: 0.1306 - val_accuracy: 0.9750
# Epoch 69/200
# 5/5 [==============================] - 2s 458ms/step - loss: 0.1000 - accuracy: 0.9862 - val_loss: 0.1303 - val_accuracy: 0.9750
# Epoch 70/200
# 5/5 [==============================] - 2s 457ms/step - loss: 0.1048 - accuracy: 0.9809 - val_loss: 0.1279 - val_accuracy: 0.9750
# Epoch 71/200
# 5/5 [==============================] - 2s 455ms/step - loss: 0.1006 - accuracy: 0.9783 - val_loss: 0.1255 - val_accuracy: 1.0000
# Epoch 72/200
# 5/5 [==============================] - 2s 460ms/step - loss: 0.1092 - accuracy: 0.9809 - val_loss: 0.1242 - val_accuracy: 1.0000
# Epoch 73/200
# 5/5 [==============================] - 2s 453ms/step - loss: 0.0943 - accuracy: 0.9779 - val_loss: 0.1238 - val_accuracy: 1.0000
# Epoch 74/200
# 5/5 [==============================] - 2s 457ms/step - loss: 0.1055 - accuracy: 1.0000 - val_loss: 0.1244 - val_accuracy: 0.9750
# Epoch 75/200
# 5/5 [==============================] - 2s 454ms/step - loss: 0.0970 - accuracy: 0.9731 - val_loss: 0.1239 - val_accuracy: 0.9750
# Epoch 76/200
# 5/5 [==============================] - 2s 459ms/step - loss: 0.0913 - accuracy: 0.9862 - val_loss: 0.1223 - val_accuracy: 0.9750
# Epoch 77/200
# 5/5 [==============================] - 2s 454ms/step - loss: 0.1117 - accuracy: 0.9731 - val_loss: 0.1206 - val_accuracy: 1.0000
# Epoch 78/200
# 5/5 [==============================] - 2s 454ms/step - loss: 0.1006 - accuracy: 0.9823 - val_loss: 0.1194 - val_accuracy: 1.0000
# Epoch 79/200
# 5/5 [==============================] - 2s 454ms/step - loss: 0.0933 - accuracy: 0.9961 - val_loss: 0.1177 - val_accuracy: 1.0000
# Epoch 80/200
# 5/5 [==============================] - 2s 459ms/step - loss: 0.0976 - accuracy: 0.9922 - val_loss: 0.1155 - val_accuracy: 1.0000
# Epoch 81/200
# 5/5 [==============================] - 2s 457ms/step - loss: 0.1115 - accuracy: 0.9675 - val_loss: 0.1138 - val_accuracy: 1.0000
# Epoch 82/200
# 5/5 [==============================] - 2s 463ms/step - loss: 0.0866 - accuracy: 0.9918 - val_loss: 0.1125 - val_accuracy: 1.0000
# Epoch 83/200
# 5/5 [==============================] - 2s 451ms/step - loss: 0.0728 - accuracy: 1.0000 - val_loss: 0.1113 - val_accuracy: 1.0000
# Epoch 84/200
# 5/5 [==============================] - 2s 452ms/step - loss: 0.0826 - accuracy: 0.9905 - val_loss: 0.1092 - val_accuracy: 1.0000
# Epoch 85/200
# 5/5 [==============================] - 2s 459ms/step - loss: 0.0929 - accuracy: 0.9805 - val_loss: 0.1068 - val_accuracy: 1.0000
# Epoch 86/200
# 5/5 [==============================] - 2s 456ms/step - loss: 0.0850 - accuracy: 0.9944 - val_loss: 0.1054 - val_accuracy: 1.0000
# Epoch 87/200
# 5/5 [==============================] - 2s 453ms/step - loss: 0.0910 - accuracy: 1.0000 - val_loss: 0.1046 - val_accuracy: 1.0000
# Epoch 88/200
# 5/5 [==============================] - 2s 457ms/step - loss: 0.0867 - accuracy: 0.9866 - val_loss: 0.1040 - val_accuracy: 1.0000
# Epoch 89/200
# 5/5 [==============================] - 2s 451ms/step - loss: 0.1009 - accuracy: 0.9866 - val_loss: 0.1036 - val_accuracy: 1.0000
# Epoch 90/200
# 5/5 [==============================] - 2s 456ms/step - loss: 0.0930 - accuracy: 0.9944 - val_loss: 0.1035 - val_accuracy: 1.0000
# Epoch 91/200
# 5/5 [==============================] - 2s 458ms/step - loss: 0.0862 - accuracy: 0.9862 - val_loss: 0.1024 - val_accuracy: 1.0000
# Epoch 92/200
# 5/5 [==============================] - 2s 453ms/step - loss: 0.0883 - accuracy: 0.9944 - val_loss: 0.1016 - val_accuracy: 1.0000
# Epoch 93/200
# 5/5 [==============================] - 2s 457ms/step - loss: 0.0791 - accuracy: 0.9879 - val_loss: 0.1014 - val_accuracy: 1.0000
# Epoch 94/200
# 5/5 [==============================] - 2s 454ms/step - loss: 0.0754 - accuracy: 1.0000 - val_loss: 0.1024 - val_accuracy: 1.0000
# Epoch 95/200
# 5/5 [==============================] - 2s 449ms/step - loss: 0.0852 - accuracy: 0.9866 - val_loss: 0.1026 - val_accuracy: 1.0000
# Epoch 96/200
# 5/5 [==============================] - 2s 448ms/step - loss: 0.0730 - accuracy: 0.9961 - val_loss: 0.1027 - val_accuracy: 1.0000
# Epoch 97/200
# 5/5 [==============================] - 2s 457ms/step - loss: 0.0806 - accuracy: 0.9918 - val_loss: 0.1024 - val_accuracy: 1.0000
# Epoch 98/200
# 5/5 [==============================] - 2s 451ms/step - loss: 0.0813 - accuracy: 0.9961 - val_loss: 0.1019 - val_accuracy: 1.0000
# Epoch 99/200
# 5/5 [==============================] - 2s 458ms/step - loss: 0.0776 - accuracy: 0.9862 - val_loss: 0.1014 - val_accuracy: 1.0000
# Epoch 100/200
# 5/5 [==============================] - 2s 457ms/step - loss: 0.0738 - accuracy: 0.9961 - val_loss: 0.1012 - val_accuracy: 1.0000
# Epoch 101/200
# 5/5 [==============================] - 2s 461ms/step - loss: 0.0768 - accuracy: 0.9905 - val_loss: 0.1004 - val_accuracy: 1.0000
# Epoch 102/200
# 5/5 [==============================] - 2s 452ms/step - loss: 0.0743 - accuracy: 1.0000 - val_loss: 0.0998 - val_accuracy: 1.0000
# Epoch 103/200
# 5/5 [==============================] - 2s 454ms/step - loss: 0.0753 - accuracy: 0.9809 - val_loss: 0.0994 - val_accuracy: 1.0000
# Epoch 104/200
# 5/5 [==============================] - 2s 449ms/step - loss: 0.0671 - accuracy: 0.9944 - val_loss: 0.0992 - val_accuracy: 1.0000
# Epoch 105/200
# 5/5 [==============================] - 2s 461ms/step - loss: 0.0680 - accuracy: 0.9866 - val_loss: 0.0987 - val_accuracy: 1.0000
# Epoch 106/200
# 5/5 [==============================] - 2s 459ms/step - loss: 0.0838 - accuracy: 1.0000 - val_loss: 0.0979 - val_accuracy: 1.0000
# Epoch 107/200
# 5/5 [==============================] - 2s 448ms/step - loss: 0.0889 - accuracy: 0.9918 - val_loss: 0.0971 - val_accuracy: 1.0000
# Epoch 108/200
# 5/5 [==============================] - 2s 451ms/step - loss: 0.0666 - accuracy: 1.0000 - val_loss: 0.0965 - val_accuracy: 1.0000
# Epoch 109/200
# 5/5 [==============================] - 2s 462ms/step - loss: 0.0667 - accuracy: 0.9961 - val_loss: 0.0961 - val_accuracy: 1.0000
# Epoch 110/200
# 5/5 [==============================] - 2s 455ms/step - loss: 0.0779 - accuracy: 1.0000 - val_loss: 0.0956 - val_accuracy: 1.0000
# Epoch 111/200
# 5/5 [==============================] - 2s 456ms/step - loss: 0.0559 - accuracy: 0.9961 - val_loss: 0.0955 - val_accuracy: 1.0000
# Epoch 112/200
# 5/5 [==============================] - 2s 457ms/step - loss: 0.0672 - accuracy: 1.0000 - val_loss: 0.0952 - val_accuracy: 1.0000
# Epoch 113/200
# 5/5 [==============================] - 2s 457ms/step - loss: 0.0766 - accuracy: 0.9918 - val_loss: 0.0948 - val_accuracy: 1.0000
# Epoch 114/200
# 5/5 [==============================] - 2s 458ms/step - loss: 0.0655 - accuracy: 0.9961 - val_loss: 0.0945 - val_accuracy: 1.0000
# Epoch 115/200
# 5/5 [==============================] - 2s 457ms/step - loss: 0.0709 - accuracy: 0.9866 - val_loss: 0.0941 - val_accuracy: 1.0000
# Epoch 116/200
# 5/5 [==============================] - 2s 460ms/step - loss: 0.0739 - accuracy: 0.9922 - val_loss: 0.0940 - val_accuracy: 1.0000
# Epoch 117/200
# 5/5 [==============================] - 2s 452ms/step - loss: 0.0610 - accuracy: 1.0000 - val_loss: 0.0930 - val_accuracy: 1.0000
# Epoch 118/200
# 5/5 [==============================] - 2s 461ms/step - loss: 0.0672 - accuracy: 0.9862 - val_loss: 0.0907 - val_accuracy: 1.0000
# Epoch 119/200
# 5/5 [==============================] - 2s 456ms/step - loss: 0.0648 - accuracy: 0.9918 - val_loss: 0.0895 - val_accuracy: 1.0000
# Epoch 120/200
# 5/5 [==============================] - 2s 448ms/step - loss: 0.0612 - accuracy: 1.0000 - val_loss: 0.0888 - val_accuracy: 1.0000
# Epoch 121/200
# 5/5 [==============================] - 2s 458ms/step - loss: 0.0664 - accuracy: 0.9922 - val_loss: 0.0884 - val_accuracy: 1.0000
# Epoch 122/200
# 5/5 [==============================] - 2s 458ms/step - loss: 0.0645 - accuracy: 1.0000 - val_loss: 0.0878 - val_accuracy: 1.0000
# Epoch 123/200
# 5/5 [==============================] - 2s 459ms/step - loss: 0.0561 - accuracy: 1.0000 - val_loss: 0.0873 - val_accuracy: 1.0000
# Epoch 124/200
# 5/5 [==============================] - 2s 456ms/step - loss: 0.0670 - accuracy: 0.9879 - val_loss: 0.0864 - val_accuracy: 1.0000
# Epoch 125/200
# 5/5 [==============================] - 2s 458ms/step - loss: 0.0747 - accuracy: 1.0000 - val_loss: 0.0848 - val_accuracy: 1.0000
# Epoch 126/200
# 5/5 [==============================] - 2s 460ms/step - loss: 0.0539 - accuracy: 1.0000 - val_loss: 0.0838 - val_accuracy: 1.0000
# Epoch 127/200
# 5/5 [==============================] - 2s 457ms/step - loss: 0.0575 - accuracy: 0.9918 - val_loss: 0.0831 - val_accuracy: 1.0000
# Epoch 128/200
# 5/5 [==============================] - 2s 460ms/step - loss: 0.0758 - accuracy: 0.9944 - val_loss: 0.0822 - val_accuracy: 1.0000
# Epoch 129/200
# 5/5 [==============================] - 2s 457ms/step - loss: 0.0606 - accuracy: 1.0000 - val_loss: 0.0817 - val_accuracy: 1.0000
# Epoch 130/200
# 5/5 [==============================] - 2s 457ms/step - loss: 0.0655 - accuracy: 0.9918 - val_loss: 0.0815 - val_accuracy: 1.0000
# Epoch 131/200
# 5/5 [==============================] - 2s 457ms/step - loss: 0.0660 - accuracy: 0.9866 - val_loss: 0.0815 - val_accuracy: 1.0000
# Epoch 132/200
# 5/5 [==============================] - 2s 461ms/step - loss: 0.0474 - accuracy: 1.0000 - val_loss: 0.0813 - val_accuracy: 1.0000
# Epoch 133/200
# 5/5 [==============================] - 2s 457ms/step - loss: 0.0543 - accuracy: 1.0000 - val_loss: 0.0800 - val_accuracy: 1.0000
# Epoch 134/200
# 5/5 [==============================] - 2s 450ms/step - loss: 0.0662 - accuracy: 1.0000 - val_loss: 0.0790 - val_accuracy: 1.0000
# Epoch 135/200
# 5/5 [==============================] - 2s 456ms/step - loss: 0.0615 - accuracy: 0.9918 - val_loss: 0.0777 - val_accuracy: 1.0000
# Epoch 136/200
# 5/5 [==============================] - 2s 460ms/step - loss: 0.0724 - accuracy: 0.9944 - val_loss: 0.0765 - val_accuracy: 1.0000
# Epoch 137/200
# 5/5 [==============================] - 2s 454ms/step - loss: 0.0630 - accuracy: 1.0000 - val_loss: 0.0751 - val_accuracy: 1.0000
# Epoch 138/200
# 5/5 [==============================] - 2s 455ms/step - loss: 0.0590 - accuracy: 1.0000 - val_loss: 0.0743 - val_accuracy: 1.0000
# Epoch 139/200
# 5/5 [==============================] - 2s 462ms/step - loss: 0.0526 - accuracy: 1.0000 - val_loss: 0.0736 - val_accuracy: 1.0000
# Epoch 140/200
# 5/5 [==============================] - 2s 458ms/step - loss: 0.0601 - accuracy: 0.9918 - val_loss: 0.0732 - val_accuracy: 1.0000
# Epoch 141/200
# 5/5 [==============================] - 2s 452ms/step - loss: 0.0528 - accuracy: 1.0000 - val_loss: 0.0729 - val_accuracy: 1.0000
# Epoch 142/200
# 5/5 [==============================] - 2s 456ms/step - loss: 0.0530 - accuracy: 1.0000 - val_loss: 0.0727 - val_accuracy: 1.0000
# Epoch 143/200
# 5/5 [==============================] - 2s 456ms/step - loss: 0.0535 - accuracy: 0.9866 - val_loss: 0.0726 - val_accuracy: 1.0000
# Epoch 144/200
# 5/5 [==============================] - 2s 456ms/step - loss: 0.0486 - accuracy: 1.0000 - val_loss: 0.0718 - val_accuracy: 1.0000
# Epoch 145/200
# 5/5 [==============================] - 2s 454ms/step - loss: 0.0734 - accuracy: 1.0000 - val_loss: 0.0713 - val_accuracy: 1.0000
# Epoch 146/200
# 5/5 [==============================] - 2s 457ms/step - loss: 0.0550 - accuracy: 1.0000 - val_loss: 0.0711 - val_accuracy: 1.0000
# Epoch 147/200
# 5/5 [==============================] - 2s 457ms/step - loss: 0.0501 - accuracy: 1.0000 - val_loss: 0.0711 - val_accuracy: 1.0000
# Epoch 148/200
# 5/5 [==============================] - 2s 455ms/step - loss: 0.0687 - accuracy: 1.0000 - val_loss: 0.0712 - val_accuracy: 1.0000
# Epoch 149/200
# 5/5 [==============================] - 2s 462ms/step - loss: 0.0519 - accuracy: 0.9944 - val_loss: 0.0713 - val_accuracy: 1.0000
# Epoch 150/200
# 5/5 [==============================] - 2s 458ms/step - loss: 0.0546 - accuracy: 1.0000 - val_loss: 0.0715 - val_accuracy: 1.0000
# Epoch 151/200
# 5/5 [==============================] - 2s 461ms/step - loss: 0.0566 - accuracy: 1.0000 - val_loss: 0.0722 - val_accuracy: 1.0000
# Epoch 152/200
# 5/5 [==============================] - 2s 457ms/step - loss: 0.0462 - accuracy: 0.9961 - val_loss: 0.0727 - val_accuracy: 1.0000
# Epoch 153/200
# 5/5 [==============================] - 2s 461ms/step - loss: 0.0564 - accuracy: 1.0000 - val_loss: 0.0729 - val_accuracy: 1.0000
# Epoch 154/200
# 5/5 [==============================] - 2s 452ms/step - loss: 0.0477 - accuracy: 1.0000 - val_loss: 0.0732 - val_accuracy: 1.0000
# Epoch 155/200
# 5/5 [==============================] - 2s 450ms/step - loss: 0.0537 - accuracy: 1.0000 - val_loss: 0.0736 - val_accuracy: 1.0000
# Epoch 156/200
# 5/5 [==============================] - 2s 460ms/step - loss: 0.0511 - accuracy: 0.9918 - val_loss: 0.0735 - val_accuracy: 1.0000
# Epoch 157/200
# 5/5 [==============================] - 2s 456ms/step - loss: 0.0511 - accuracy: 1.0000 - val_loss: 0.0727 - val_accuracy: 1.0000
# Epoch 158/200
# 5/5 [==============================] - 2s 454ms/step - loss: 0.0520 - accuracy: 1.0000 - val_loss: 0.0718 - val_accuracy: 1.0000
# Epoch 159/200
# 5/5 [==============================] - 2s 463ms/step - loss: 0.0514 - accuracy: 1.0000 - val_loss: 0.0704 - val_accuracy: 1.0000
# Epoch 160/200
# 5/5 [==============================] - 2s 454ms/step - loss: 0.0484 - accuracy: 1.0000 - val_loss: 0.0694 - val_accuracy: 1.0000
# Epoch 161/200
# 5/5 [==============================] - 2s 458ms/step - loss: 0.0507 - accuracy: 1.0000 - val_loss: 0.0683 - val_accuracy: 1.0000
# Epoch 162/200
# 5/5 [==============================] - 2s 453ms/step - loss: 0.0531 - accuracy: 0.9918 - val_loss: 0.0677 - val_accuracy: 1.0000
# Epoch 163/200
# 5/5 [==============================] - 2s 458ms/step - loss: 0.0541 - accuracy: 1.0000 - val_loss: 0.0673 - val_accuracy: 1.0000
# Epoch 164/200
# 5/5 [==============================] - 2s 455ms/step - loss: 0.0412 - accuracy: 1.0000 - val_loss: 0.0670 - val_accuracy: 1.0000
# Epoch 165/200
# 5/5 [==============================] - 2s 455ms/step - loss: 0.0420 - accuracy: 1.0000 - val_loss: 0.0670 - val_accuracy: 1.0000
# Epoch 166/200
# 5/5 [==============================] - 2s 457ms/step - loss: 0.0446 - accuracy: 0.9944 - val_loss: 0.0668 - val_accuracy: 1.0000
# Epoch 167/200
# 5/5 [==============================] - 2s 454ms/step - loss: 0.0482 - accuracy: 1.0000 - val_loss: 0.0663 - val_accuracy: 1.0000
# Epoch 168/200
# 5/5 [==============================] - 2s 456ms/step - loss: 0.0509 - accuracy: 1.0000 - val_loss: 0.0649 - val_accuracy: 1.0000
# Epoch 169/200
# 5/5 [==============================] - 2s 460ms/step - loss: 0.0463 - accuracy: 0.9944 - val_loss: 0.0641 - val_accuracy: 1.0000
# Epoch 170/200
# 5/5 [==============================] - 2s 461ms/step - loss: 0.0432 - accuracy: 1.0000 - val_loss: 0.0635 - val_accuracy: 1.0000
# Epoch 171/200
# 5/5 [==============================] - 2s 459ms/step - loss: 0.0436 - accuracy: 1.0000 - val_loss: 0.0632 - val_accuracy: 1.0000
# Epoch 172/200
# 5/5 [==============================] - 2s 458ms/step - loss: 0.0488 - accuracy: 1.0000 - val_loss: 0.0631 - val_accuracy: 1.0000
# Epoch 173/200
# 5/5 [==============================] - 2s 459ms/step - loss: 0.0449 - accuracy: 1.0000 - val_loss: 0.0630 - val_accuracy: 1.0000
# Epoch 174/200
# 5/5 [==============================] - 2s 456ms/step - loss: 0.0423 - accuracy: 1.0000 - val_loss: 0.0631 - val_accuracy: 1.0000
# Epoch 175/200
# 5/5 [==============================] - 2s 455ms/step - loss: 0.0439 - accuracy: 1.0000 - val_loss: 0.0633 - val_accuracy: 1.0000
# Epoch 176/200
# 5/5 [==============================] - 2s 458ms/step - loss: 0.0485 - accuracy: 1.0000 - val_loss: 0.0634 - val_accuracy: 1.0000
# Epoch 177/200
# 5/5 [==============================] - 2s 459ms/step - loss: 0.0433 - accuracy: 1.0000 - val_loss: 0.0635 - val_accuracy: 1.0000
# Epoch 178/200
# 5/5 [==============================] - 2s 454ms/step - loss: 0.0490 - accuracy: 1.0000 - val_loss: 0.0638 - val_accuracy: 1.0000
# Epoch 179/200
# 5/5 [==============================] - 2s 459ms/step - loss: 0.0439 - accuracy: 1.0000 - val_loss: 0.0641 - val_accuracy: 1.0000
# Epoch 180/200
# 5/5 [==============================] - 2s 454ms/step - loss: 0.0461 - accuracy: 1.0000 - val_loss: 0.0641 - val_accuracy: 1.0000
# Epoch 181/200
# 5/5 [==============================] - 2s 452ms/step - loss: 0.0430 - accuracy: 1.0000 - val_loss: 0.0642 - val_accuracy: 1.0000
# Epoch 182/200
# 5/5 [==============================] - 2s 461ms/step - loss: 0.0464 - accuracy: 1.0000 - val_loss: 0.0642 - val_accuracy: 1.0000
# Epoch 183/200
# 5/5 [==============================] - 2s 463ms/step - loss: 0.0491 - accuracy: 0.9944 - val_loss: 0.0641 - val_accuracy: 1.0000
# Epoch 184/200
# 5/5 [==============================] - 2s 462ms/step - loss: 0.0350 - accuracy: 1.0000 - val_loss: 0.0641 - val_accuracy: 1.0000
# Epoch 185/200
# 5/5 [==============================] - 2s 457ms/step - loss: 0.0482 - accuracy: 1.0000 - val_loss: 0.0641 - val_accuracy: 1.0000
# Epoch 186/200
# 5/5 [==============================] - 2s 460ms/step - loss: 0.0514 - accuracy: 0.9866 - val_loss: 0.0636 - val_accuracy: 1.0000
# Epoch 187/200
# 5/5 [==============================] - 2s 456ms/step - loss: 0.0385 - accuracy: 1.0000 - val_loss: 0.0628 - val_accuracy: 1.0000
# Epoch 188/200
# 5/5 [==============================] - 2s 461ms/step - loss: 0.0513 - accuracy: 1.0000 - val_loss: 0.0623 - val_accuracy: 1.0000
# Epoch 189/200
# 5/5 [==============================] - 2s 456ms/step - loss: 0.0528 - accuracy: 1.0000 - val_loss: 0.0618 - val_accuracy: 1.0000
# Epoch 190/200
# 5/5 [==============================] - 2s 462ms/step - loss: 0.0492 - accuracy: 1.0000 - val_loss: 0.0614 - val_accuracy: 1.0000
# Epoch 191/200
# 5/5 [==============================] - 2s 456ms/step - loss: 0.0498 - accuracy: 1.0000 - val_loss: 0.0610 - val_accuracy: 1.0000
# Epoch 192/200
# 5/5 [==============================] - 2s 460ms/step - loss: 0.0393 - accuracy: 1.0000 - val_loss: 0.0610 - val_accuracy: 1.0000
# Epoch 193/200
# 5/5 [==============================] - 2s 454ms/step - loss: 0.0368 - accuracy: 1.0000 - val_loss: 0.0619 - val_accuracy: 1.0000
# Epoch 194/200
# 5/5 [==============================] - 2s 458ms/step - loss: 0.0444 - accuracy: 1.0000 - val_loss: 0.0623 - val_accuracy: 1.0000
# Epoch 195/200
# 5/5 [==============================] - 2s 458ms/step - loss: 0.0377 - accuracy: 1.0000 - val_loss: 0.0625 - val_accuracy: 1.0000
# Epoch 196/200
# 5/5 [==============================] - 2s 458ms/step - loss: 0.0467 - accuracy: 0.9918 - val_loss: 0.0624 - val_accuracy: 1.0000
# Epoch 197/200
# 5/5 [==============================] - 2s 464ms/step - loss: 0.0378 - accuracy: 0.9944 - val_loss: 0.0623 - val_accuracy: 1.0000
# Epoch 198/200
# 5/5 [==============================] - 2s 461ms/step - loss: 0.0373 - accuracy: 1.0000 - val_loss: 0.0619 - val_accuracy: 1.0000
# Epoch 199/200
# 5/5 [==============================] - 2s 457ms/step - loss: 0.0441 - accuracy: 1.0000 - val_loss: 0.0614 - val_accuracy: 1.0000
# Epoch 200/200
# 5/5 [==============================] - 2s 457ms/step - loss: 0.0437 - accuracy: 0.9961 - val_loss: 0.0609 - val_accuracy: 1.0000

# %% [markdown]
# ### Visualization of training and validation curves of transfer learning

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs_range = range(epochs)

plt.figure(figsize=(15, 15))
plt.subplot(2, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(2, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# Here we can see, that the training process shows most likely underfitting. We could now increase the learning rate and/or epochs.

# %% [markdown]
# ## Inference on transfer learning

# %%
# pick random image from the inference folder
rdm_img = random.choice(inference_files)
image_size = (img_size,img_size)

# predict
img = keras.preprocessing.image.load_img(
    rdm_img, target_size=image_size
    )
img_array = keras.preprocessing.image.img_to_array(img)
img_array = tf.expand_dims(img_array, 0)
predictions = model.predict(img_array)

# get score
score = predictions[0]
print(
    'This image is %.1f percent %s and %.1f percent %s.'
    %(score[0] * 100, classes[0], score[1] * 100, classes[1]))
Image(filename=rdm_img)
# Out:
# This image is 71.0 percent beach and 29.0 percent forest.

# %% [markdown]
# In this example, transfer learning did apparently not make our predictions better.

# %%
model_save_path = HOME + 'models/beachforest_50epo_transfer'
model.save(model_save_path)
# Out:
# INFO:tensorflow:Assets written to: /content/Data/models/beachforest_50epo_transfer/assets

# %% [markdown]
# ## References
#
# - https://keras.io/examples/vision/image_classification_from_scratch/
# - https://www.analyticsvidhya.com/blog/2020/10/create-image-classification-model-python-keras/
